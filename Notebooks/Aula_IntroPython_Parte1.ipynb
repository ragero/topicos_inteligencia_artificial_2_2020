# %% [markdown]
# # Tipos Básicos

# %% [markdown]
# ## Inteiros

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
type(a)
# Out:
# int

# %% [markdown]
# ## Float

# %%
b = 10.5

# %%
print(b)
# Out:
# 10.5

# %%
type(b)
# Out:
# float

# %% [markdown]
# ## Boolean

# %%
c = False

# %%
print(c)
# Out:
# False

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ## String

# %%
d = "Aula 'de' Python"

# %%
print(d)
# Out:
# Aula 'de' Python

# %%
type(d)
# Out:
# str

# %%
e = 'Aula de "Python" 2'

# %%
print(e)
# Out:
# Aula de "Python" 2

# %%
type(e)
# Out:
# str
