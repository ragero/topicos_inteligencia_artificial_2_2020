# %% [markdown]
# # Importações

# %%
# Carregar e visualizar os dados
import pandas as pd

#Biblioteca para gerar e manipular as word embeddings
import gensim
from gensim.models import KeyedVectors

#Biblioteca para preprocessar os textos 
import spacy

#O tqdm é utilizado para exibir uma barra de progresso
#Os demais comandos são utilizados para o correto funcionamento no Colab
from tqdm import tqdm
from IPython import get_ipython
def tqdm_clear(*args, **kwargs):
    getattr(tqdm, '_instances', {}).clear()

# %% [markdown]
# #Base de Dados

# %%
df = pd.read_csv('/content/drive/My Drive/Datasets/Texts/AmazonFoodReviews.csv')

# %%
df.head(10)
# Out:
#    Score  ...                                               Text
# 0      5  ...  I have bought several of the Vitality canned d...
# 1      1  ...  Product arrived labeled as Jumbo Salted Peanut...
# 2      4  ...  This is a confection that has been around a fe...
# 3      2  ...  If you are looking for the secret ingredient i...
# 4      5  ...  Great taffy at a great price.  There was a wid...
# 5      4  ...  I got a wild hair for taffy and ordered this f...
# 6      5  ...  This saltwater taffy had great flavors and was...
# 7      5  ...  This taffy is so good.  It is very soft and ch...
# 8      5  ...  Right now I'm mostly just sprouting this so my...
# 9      5  ...  This is a very healthy dog food. Good for thei...
#
# [10 rows x 3 columns]

# %% [markdown]
# #Pré-processando os Textos da Coleção

# %%
# Initializando o spacy, porém, desabilitando recursos que não iremos utilizar
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
def preprocessamento (texto): 
  final_tokens = []
  doc = nlp(texto)
  for token in doc:
    if(token.is_alpha and not token.is_stop):
          final_tokens.append(token.lemma_.lower())
      
  return ' '.join(final_tokens)

# %%
tqdm.pandas()
df['Tokens'] = df['Text'].progress_apply(preprocessamento)
# Out:
# 100%|██████████| 568454/568454 [53:16<00:00, 177.83it/s]

# %%
#Salvando para garantir
df.to_csv('/content/drive/My Drive/Datasets/Texts/AmazonFoodReviewsWithTokens.csv', index=False)

# %%
df.head(n=10)
# Out:
#    Score  ...                                             Tokens
# 0      5  ...  [buy, vitality, can, dog, food, product, find,...
# 1      1  ...  [product, arrive, label, jumbo, salt, peanut, ...
# 2      4  ...  [confection, century, light, pillowy, citrus, ...
# 3      2  ...  [look, secret, ingredient, robitussin, believe...
# 4      5  ...  [great, taffy, great, price, wide, assortment,...
# 5      4  ...  [get, wild, hair, taffy, order, pound, bag, ta...
# 6      5  ...  [saltwater, taffy, great, flavor, soft, chewy,...
# 7      5  ...  [taffy, good, soft, chewy, flavor, amazing, de...
# 8      5  ...  [right, sprout, cat, eat, grass, love, rotate,...
# 9      5  ...  [healthy, dog, food, good, digestion, good, sm...
#
# [10 rows x 4 columns]

# %% [markdown]
# #Treinando as Word Embeddings

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# ###Skip-Gram

# %%
#Gerando o modelo SkipGram

#Primeiro parâmetros: coleção de textos
#sg=1: arquitetura do tipo Skip-Gram
#min_count=5: número mínimo de vezes que uma palavra deve aparecer ao longo da coleção
#window: tamanho do contexto
#size: número de dimenções da embedding
modelo_w2v_sg = gensim.models.Word2Vec(df['Tokens'],sg=1,min_count=5,window=10, size=100)

# %%
#Salvando o modelo inteiro SkipGram
modelo_w2v_sg.save("/content/drive/My Drive/Datasets/Texts/AmazonFoodReviews_model_w2v.model")
#Salvando apenas as Word Embeddings
modelo_w2v_sg.wv.save("/content/drive/My Drive/Datasets/Texts/AmazonFoodReviews_model_w2v.kv")

#Posteriormente para carregar ambos fica
#modelo_w2v_sg = gensim.models.Word2Vec.load("/content/drive/My Drive/Datasets/Texts/AmazonFoodReviews_model_w2v.model") 
#wv_kv_sg = gensim.models.KeyedVectors.load("/content/drive/My Drive/Datasets/Texts/AmazonFoodReviews_model_w2v.kv", mmap='r')

# %% [markdown]
# ### CBOW

# %%
#Parâmetros similares ao Skip-Gram, porém, com sg=0
modelo_w2v_cbow = gensim.models.Word2Vec(df['Tokens'],sg=1,min_count=5,window=10, size=100)

# %% [markdown]
# # FastText

# %%
#Parêmtros similares aos da abordagem Word2Vec, porém, o modelo utilizado é o FastText
modelo_ft = gensim.models.FastText(df['Tokens'],min_count=5,window=10, size=100)

# %% [markdown]
# # Consultando as Palavras Mais Similares nos Diferentes Modelos

# %%
#Consultando as 20 palavras mais similares a 'cheese' no modelo skipgram
modelo_w2v_sg.wv.most_similar('cheese', topn=20)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('cheddar', 0.805945634841919),
#  ('asiago', 0.7987725734710693),
#  ('macaroni', 0.7951961755752563),
#  ('havarti', 0.7851487398147583),
#  ('mozzarella', 0.7811793684959412),
#  ('mac', 0.7750540971755981),
#  ('chevre', 0.7730174660682678),
#  ('curds', 0.7673276662826538),
#  ('cheesier', 0.7610152363777161),
#  ('parmesan', 0.7524831891059875),
#  ('brie', 0.7496126890182495),
#  ('castello', 0.747927725315094),
#  ('dofino', 0.7445870637893677),
#  ('cheesy', 0.7418321371078491),
#  ('chedder', 0.7398743629455566),
#  ('roquefort', 0.7304426431655884),
#  ('provolone', 0.7300024032592773),
#  ('velveeta', 0.7291139364242554),
#  ('romano', 0.7269539833068848),
#  ('chedar', 0.7259482145309448)]

# %%
#Consultando as 20 palavras mais similares a 'cheese' no modelo cbow
modelo_w2v_cbow.wv.most_similar('cheese', topn=20)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('asiago', 0.7946245074272156),
#  ('cheddar', 0.7904796600341797),
#  ('mozzarella', 0.7788733839988708),
#  ('macaroni', 0.7728685140609741),
#  ('chedar', 0.7703266143798828),
#  ('havarti', 0.7702367305755615),
#  ('parmesan', 0.7679916620254517),
#  ('cheesier', 0.7597986459732056),
#  ('chevre', 0.7589219212532043),
#  ('brie', 0.7582805156707764),
#  ('mac', 0.757365345954895),
#  ('curds', 0.7530713081359863),
#  ('provolone', 0.7515742778778076),
#  ('chedder', 0.7480548620223999),
#  ('dofino', 0.7386725544929504),
#  ('chesse', 0.738013505935669),
#  ('castello', 0.735872745513916),
#  ('cheesy', 0.7305408120155334),
#  ('mascarpone', 0.728222668170929),
#  ('grated', 0.722386360168457)]

# %%
modelo_ft.wv.most_similar('cheese', topn=20)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('cheeese', 0.9560588002204895),
#  ('cheesey', 0.9551533460617065),
#  ('cheeses', 0.9144033789634705),
#  ('theese', 0.8912648558616638),
#  ('cheesesteak', 0.8825253248214722),
#  ('cheesestick', 0.8648257255554199),
#  ('cheeseburger', 0.8571553230285645),
#  ('cheesiest', 0.8520803451538086),
#  ('cheesier', 0.8470945358276367),
#  ('cheeseball', 0.8310973048210144),
#  ('cheesy', 0.8292456865310669),
#  ('cheesoning', 0.8183912038803101),
#  ('cheesecloth', 0.8124037981033325),
#  ('cheesburger', 0.8101001977920532),
#  ('cheezwhiz', 0.8055063486099243),
#  ('cheezy', 0.798599123954773),
#  ('cheez', 0.7783213257789612),
#  ('creamcheese', 0.777782678604126),
#  ('cheezit', 0.7625910043716431),
#  ('cheeze', 0.7613284587860107)]

# %% [markdown]
# #Obtendo os Vetores das Palavras

# %%
modelo_ft.wv.get_vector('cheese')
# Out:
# array([-0.08184408, -2.2311382 , -2.492365  ,  3.257404  , -1.9422194 ,
#         2.7177088 , -2.2955086 ,  1.1486218 ,  0.23529346, -3.368218  ,
#         3.7355335 , -0.5069643 , -0.5499422 ,  2.2903469 ,  1.134696  ,
#         2.670308  ,  1.4461482 ,  1.8927674 ,  0.5051987 ,  2.8341556 ,
#         0.06283331, -1.2707167 ,  2.4234438 ,  3.8059785 ,  6.4608674 ,
#        -2.1753607 ,  1.2648573 , -0.63337964,  0.5241564 ,  1.577323  ,
#        -3.2373915 ,  0.24699497, -3.226584  ,  1.8641607 , -1.2343727 ,
#         0.91023755, -0.64831525, -1.6202412 ,  2.9555364 ,  0.03749143,
#        -1.249742  ,  0.72780824,  1.9836384 ,  0.7922271 ,  0.61221975,
#         2.5431392 , -0.2680755 , -0.97211474,  1.9580075 , -2.5684462 ,
#        -2.4829323 , -4.6846886 ,  3.1529284 ,  0.4547629 ,  0.63352   ,
#        -0.92202497,  1.4747317 , -3.1064172 ,  1.7622886 ,  1.0706652 ,
#         3.3747735 ,  2.7456727 , -1.2298013 ,  0.18480334, -0.08525322,
#         0.06383915, -1.4466848 , -1.2302431 , -2.2721653 ,  0.5438325 ,
#         0.23929164,  2.061094  , -1.9152647 , -1.6816345 ,  5.0137157 ,
#        -0.4684928 , -3.3816793 , -0.50966525, -0.6277265 ,  2.7712235 ,
#        -2.5231051 , -1.1305914 ,  3.2711911 ,  1.3839298 , -0.14325617,
#         3.2096603 , -1.3854288 , -4.3913    ,  1.3392607 ,  1.740242  ,
#         2.7164276 , -3.2798443 , -0.8215159 ,  1.4788042 , -1.1073765 ,
#        -3.3337224 ,  0.38307628, -4.1604705 , -3.0822718 , -3.717763  ],
#       dtype=float32)

# %% [markdown]
# #Obtendo os Velores Mais Parecidos Após Operações com os Vetores das Palavras

# %%
#positive: soma
#negative: subtrai
modelo_w2v_cbow.wv.most_similar('avocado', topn=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('avocados', 0.6898744702339172)]

# %%
modelo_w2v_cbow.wv.most_similar(positive=['avocado','salsa'], topn=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('guacamole', 0.7307560443878174)]

# %%
modelo_w2v_cbow.wv.most_similar(positive=['avocado','salsa'],negative=['salt'], topn=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('avocados', 0.58322674036026)]

# %%
modelo_w2v_cbow.wv.most_similar(positive=['lemon','water'], topn=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('lemonaide', 0.7784677743911743)]

# %% [markdown]
# # Vocabulário do Modelo

# %%
"""Além de retornar o vocabulário pode ser utilizado para
   verificar se uma palavra pertence ao vocabulário de treinamento"""
modelo_w2v_cbow.wv.vocab
# Out:
# {'buy': <gensim.models.keyedvectors.Vocab at 0x7f0d774bdc18>,
#  'vitality': <gensim.models.keyedvectors.Vocab at 0x7f0d754a98d0>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9940>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9978>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f0d754a99b0>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7f0d754a99e8>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9a20>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9a58>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9a90>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9ac8>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9b00>,
#  'stew': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9b38>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9b70>,
#  'meat': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9ba8>,
#  'smell': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9be0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9c18>,
#  'labrador': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9c50>,
#  'finicky': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9c88>,
#  'appreciate': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9cc0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9cf8>,
#  'arrive': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9d30>,
#  'label': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9d68>,
#  'jumbo': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9da0>,
#  'salt': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9dd8>,
#  'peanut': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9e10>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9e48>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9e80>,
#  'sized': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9eb8>,
#  'unsalted': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9ef0>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9f28>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9f60>,
#  'vendor': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9f98>,
#  'intend': <gensim.models.keyedvectors.Vocab at 0x7f0d754a9fd0>,
#  'represent': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5048>,
#  'confection': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5080>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x7f0d754d50b8>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7f0d754d50f0>,
#  'pillowy': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5128>,
#  'citrus': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5160>,
#  'gelatin': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5198>,
#  'nut': <gensim.models.keyedvectors.Vocab at 0x7f0d754d51d0>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5208>,
#  'filbert': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5240>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5278>,
#  'tiny': <gensim.models.keyedvectors.Vocab at 0x7f0d754d52b0>,
#  'square': <gensim.models.keyedvectors.Vocab at 0x7f0d754d52e8>,
#  'liberally': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5320>,
#  'coat': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5358>,
#  'powdered': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5390>,
#  'sugar': <gensim.models.keyedvectors.Vocab at 0x7f0d754d53c8>,
#  'mouthful': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5400>,
#  'heaven': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5438>,
#  'chewy': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5470>,
#  'flavorful': <gensim.models.keyedvectors.Vocab at 0x7f0d754d54a8>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x7f0d754d54e0>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5518>,
#  'yummy': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5550>,
#  'treat': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5588>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x7f0d754d55c0>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7f0d754d55f8>,
#  'lewis': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5630>,
#  'lion': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5668>,
#  'witch': <gensim.models.keyedvectors.Vocab at 0x7f0d754d56a0>,
#  'wardrobe': <gensim.models.keyedvectors.Vocab at 0x7f0d754d56d8>,
#  'seduce': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5710>,
#  'edmund': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5748>,
#  'sell': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5780>,
#  'brother': <gensim.models.keyedvectors.Vocab at 0x7f0d754d57b8>,
#  'sisters': <gensim.models.keyedvectors.Vocab at 0x7f0d754d57f0>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5828>,
#  'ingredient': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5860>,
#  'robitussin': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5898>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7f0d754d58d0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5908>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5940>,
#  'root': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5978>,
#  'beer': <gensim.models.keyedvectors.Vocab at 0x7f0d754d59b0>,
#  'extract': <gensim.models.keyedvectors.Vocab at 0x7f0d754d59e8>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5a20>,
#  'cherry': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5a58>,
#  'soda': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5a90>,
#  'flavor': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5ac8>,
#  'medicinal': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5b00>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5b38>,
#  'taffy': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5b70>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5ba8>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5be0>,
#  'assortment': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5c18>,
#  'delivery': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5c50>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5c88>,
#  'lover': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5cc0>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5cf8>,
#  'wild': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5d30>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5d68>,
#  'pound': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5da0>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5dd8>,
#  'enjoyable': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5e10>,
#  'watermelon': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5e48>,
#  'melon': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5e80>,
#  'peppermint': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5eb8>,
#  'grape': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5ef0>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5f28>,
#  'complaint': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5f60>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5f98>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x7f0d754d5fd0>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8048>,
#  'licorice': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8080>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x7f0d754d80b8>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x7f0d754d80f0>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8128>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8160>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8198>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7f0d754d81d0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8208>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8240>,
#  'delightful': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8278>,
#  'saltwater': <gensim.models.keyedvectors.Vocab at 0x7f0d754d82b0>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x7f0d754d82e8>,
#  'candy': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8320>,
#  'individually': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8358>,
#  'wrap': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8390>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x7f0d754d83c8>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8400>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8438>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8470>,
#  'fralinger': <gensim.models.keyedvectors.Vocab at 0x7f0d754d84a8>,
#  'serve': <gensim.models.keyedvectors.Vocab at 0x7f0d754d84e0>,
#  'beach': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8518>,
#  'theme': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8550>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8588>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f0d754d85c0>,
#  'amazing': <gensim.models.keyedvectors.Vocab at 0x7f0d754d85f8>,
#  'definitely': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8630>,
#  'satisfying': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8668>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f0d754d86a0>,
#  'sprout': <gensim.models.keyedvectors.Vocab at 0x7f0d754d86d8>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8710>,
#  'eat': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8748>,
#  'grass': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8780>,
#  'rotate': <gensim.models.keyedvectors.Vocab at 0x7f0d754d87b8>,
#  'wheatgrass': <gensim.models.keyedvectors.Vocab at 0x7f0d754d87f0>,
#  'rye': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8828>,
#  'healthy': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8860>,
#  'digestion': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8898>,
#  'puppy': <gensim.models.keyedvectors.Vocab at 0x7f0d754d88d0>,
#  'required': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8908>,
#  'feeding': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8940>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8978>,
#  'cactus': <gensim.models.keyedvectors.Vocab at 0x7f0d754d89b0>,
#  'tequila': <gensim.models.keyedvectors.Vocab at 0x7f0d754d89e8>,
#  'unique': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8a20>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8a58>,
#  'flavour': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8a90>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8ac8>,
#  'sauce': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8b00>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8b38>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8b70>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8ba8>,
#  'bottle': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8be0>,
#  'trip': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8c18>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8c50>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8c88>,
#  'totally': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8cc0>,
#  'blow': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8cf8>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8d30>,
#  'realize': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8d68>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8da0>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8dd8>,
#  'magic': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8e10>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8e48>,
#  'ecstatic': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8e80>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8eb8>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8ef0>,
#  'tastelessly': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8f28>,
#  'burn': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8f60>,
#  'throat': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8f98>,
#  'grab': <gensim.models.keyedvectors.Vocab at 0x7f0d754d8fd0>,
#  'picante': <gensim.models.keyedvectors.Vocab at 0x7f0d754db048>,
#  'gourmet': <gensim.models.keyedvectors.Vocab at 0x7f0d754db080>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x7f0d754db0b8>,
#  'taste': <gensim.models.keyedvectors.Vocab at 0x7f0d754db0f0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f0d754db128>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x7f0d754db160>,
#  'incredible': <gensim.models.keyedvectors.Vocab at 0x7f0d754db198>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x7f0d754db1d0>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x7f0d754db208>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f0d754db240>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x7f0d754db278>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x7f0d754db2b0>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x7f0d754db2e8>,
#  'chubby': <gensim.models.keyedvectors.Vocab at 0x7f0d754db320>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x7f0d754db358>,
#  'protein': <gensim.models.keyedvectors.Vocab at 0x7f0d754db390>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7f0d754db3c8>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x7f0d754db400>,
#  'skinny': <gensim.models.keyedvectors.Vocab at 0x7f0d754db438>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x7f0d754db470>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f0d754db4a8>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x7f0d754db4e0>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f0d754db518>,
#  'stale': <gensim.models.keyedvectors.Vocab at 0x7f0d754db550>,
#  'ounce': <gensim.models.keyedvectors.Vocab at 0x7f0d754db588>,
#  'happily': <gensim.models.keyedvectors.Vocab at 0x7f0d754db5c0>,
#  'felidae': <gensim.models.keyedvectors.Vocab at 0x7f0d754db5f8>,
#  'platinum': <gensim.models.keyedvectors.Vocab at 0x7f0d754db630>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f0d754db668>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f0d754db6a0>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x7f0d754db6d8>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7f0d754db710>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7f0d754db748>,
#  'bowl': <gensim.models.keyedvectors.Vocab at 0x7f0d754db780>,
#  'kitty': <gensim.models.keyedvectors.Vocab at 0x7f0d754db7b8>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x7f0d754db7f0>,
#  'notice': <gensim.models.keyedvectors.Vocab at 0x7f0d754db828>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f0d754db860>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x7f0d754db898>,
#  'relate': <gensim.models.keyedvectors.Vocab at 0x7f0d754db8d0>,
#  'formula': <gensim.models.keyedvectors.Vocab at 0x7f0d754db908>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7f0d754db940>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7f0d754db978>,
#  'unfortunately': <gensim.models.keyedvectors.Vocab at 0x7f0d754db9b0>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f0d754db9e8>,
#  'securely': <gensim.models.keyedvectors.Vocab at 0x7f0d754dba20>,
#  'pack': <gensim.models.keyedvectors.Vocab at 0x7f0d754dba58>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x7f0d754dba90>,
#  'delicious': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbac8>,
#  'twizzler': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbb00>,
#  'strawberry': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbb38>,
#  'twizzlers': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbb70>,
#  'guilty': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbba8>,
#  'pleasure': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbbe0>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbc18>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbc50>,
#  'shipment': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbc88>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbcc0>,
#  'spot': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbcf8>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbd30>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbd68>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbda0>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbdd8>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbe10>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbe48>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbe80>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbeb8>,
#  'zip': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbef0>,
#  'lock': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbf28>,
#  'baggie': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbf60>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbf98>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f0d754dbfd0>,
#  'satisfied': <gensim.models.keyedvectors.Vocab at 0x7f0d754de048>,
#  'purchase': <gensim.models.keyedvectors.Vocab at 0x7f0d754de080>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7f0d754de0b8>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x7f0d754de0f0>,
#  'childhood': <gensim.models.keyedvectors.Vocab at 0x7f0d754de128>,
#  'lancaster': <gensim.models.keyedvectors.Vocab at 0x7f0d754de160>,
#  'pennsylvania': <gensim.models.keyedvectors.Vocab at 0x7f0d754de198>,
#  'y': <gensim.models.keyedvectors.Vocab at 0x7f0d754de1d0>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7f0d754de208>,
#  'candies': <gensim.models.keyedvectors.Vocab at 0x7f0d754de240>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f0d754de278>,
#  'confectionery': <gensim.models.keyedvectors.Vocab at 0x7f0d754de2b0>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x7f0d754de2e8>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x7f0d754de320>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x7f0d754de358>,
#  'subsidiary': <gensim.models.keyedvectors.Vocab at 0x7f0d754de390>,
#  'hershey': <gensim.models.keyedvectors.Vocab at 0x7f0d754de3c8>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x7f0d754de400>,
#  'establish': <gensim.models.keyedvectors.Vocab at 0x7f0d754de438>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f0d754de470>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x7f0d754de4a8>,
#  'twists': <gensim.models.keyedvectors.Vocab at 0x7f0d754de4e0>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x7f0d754de518>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x7f0d754de550>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x7f0d754de588>,
#  'raspberry': <gensim.models.keyedvectors.Vocab at 0x7f0d754de5c0>,
#  'br': <gensim.models.keyedvectors.Vocab at 0x7f0d754de5f8>,
#  'dry': <gensim.models.keyedvectors.Vocab at 0x7f0d754de630>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7f0d754de668>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7f0d754de6a0>,
#  'fridge': <gensim.models.keyedvectors.Vocab at 0x7f0d754de6d8>,
#  'accord': <gensim.models.keyedvectors.Vocab at 0x7f0d754de710>,
#  'guinness': <gensim.models.keyedvectors.Vocab at 0x7f0d754de748>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f0d754de780>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f0d754de7b8>,
#  'twist': <gensim.models.keyedvectors.Vocab at 0x7f0d754de7f0>,
#  'measure': <gensim.models.keyedvectors.Vocab at 0x7f0d754de828>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x7f0d754de860>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x7f0d754de898>,
#  'kg': <gensim.models.keyedvectors.Vocab at 0x7f0d754de8d0>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x7f0d754de908>,
#  'breaking': <gensim.models.keyedvectors.Vocab at 0x7f0d754de940>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f0d754de978>,
#  'july': <gensim.models.keyedvectors.Vocab at 0x7f0d754de9b0>,
#  'kosher': <gensim.models.keyedvectors.Vocab at 0x7f0d754de9e8>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7f0d754dea20>,
#  'deliver': <gensim.models.keyedvectors.Vocab at 0x7f0d754dea58>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x7f0d754dea90>,
#  'reasonable': <gensim.models.keyedvectors.Vocab at 0x7f0d754deac8>,
#  'bind': <gensim.models.keyedvectors.Vocab at 0x7f0d754deb00>,
#  'unable': <gensim.models.keyedvectors.Vocab at 0x7f0d754deb38>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x7f0d754deb70>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x7f0d754deba8>,
#  'addict': <gensim.models.keyedvectors.Vocab at 0x7f0d754debe0>,
#  'amazon': <gensim.models.keyedvectors.Vocab at 0x7f0d754dec18>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x7f0d754dec50>,
#  'employee': <gensim.models.keyedvectors.Vocab at 0x7f0d754dec88>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f0d754decc0>,
#  'overseas': <gensim.models.keyedvectors.Vocab at 0x7f0d754decf8>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x7f0d754ded30>,
#  'assign': <gensim.models.keyedvectors.Vocab at 0x7f0d754ded68>,
#  'tasty': <gensim.models.keyedvectors.Vocab at 0x7f0d754deda0>,
#  'timely': <gensim.models.keyedvectors.Vocab at 0x7f0d754dedd8>,
#  'manner': <gensim.models.keyedvectors.Vocab at 0x7f0d754dee10>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x7f0d754dee48>,
#  'apparently': <gensim.models.keyedvectors.Vocab at 0x7f0d754dee80>,
#  'staff': <gensim.models.keyedvectors.Vocab at 0x7f0d754deeb8>,
#  'generous': <gensim.models.keyedvectors.Vocab at 0x7f0d754deef0>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7f0d754def28>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7f0d754def60>,
#  'gp': <gensim.models.keyedvectors.Vocab at 0x7f0d754def98>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7f0d754defd0>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2048>,
#  'superb': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2080>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f0d754e20b8>,
#  'disappoint': <gensim.models.keyedvectors.Vocab at 0x7f0d754e20f0>,
#  'watcher': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2128>,
#  'craving': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2160>,
#  'yrs': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2198>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x7f0d754e21d0>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2208>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2240>,
#  'mexico': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2278>,
#  'faithful': <gensim.models.keyedvectors.Vocab at 0x7f0d754e22b0>,
#  'buyer': <gensim.models.keyedvectors.Vocab at 0x7f0d754e22e8>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2320>,
#  'receive': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2358>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2390>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x7f0d754e23c8>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2400>,
#  'battery': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2438>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2470>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x7f0d754e24a8>,
#  'garage': <gensim.models.keyedvectors.Vocab at 0x7f0d754e24e0>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2518>,
#  'mum': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2550>,
#  'diabetic': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2588>,
#  'intake': <gensim.models.keyedvectors.Vocab at 0x7f0d754e25c0>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x7f0d754e25f8>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2630>,
#  'limit': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2668>,
#  'unnecessary': <gensim.models.keyedvectors.Vocab at 0x7f0d754e26a0>,
#  'tooth': <gensim.models.keyedvectors.Vocab at 0x7f0d754e26d8>,
#  'toffee': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2710>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2748>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2780>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x7f0d754e27b8>,
#  'guilt': <gensim.models.keyedvectors.Vocab at 0x7f0d754e27f0>,
#  'impressed': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2828>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2860>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2898>,
#  'chocolate': <gensim.models.keyedvectors.Vocab at 0x7f0d754e28d0>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2908>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2940>,
#  'snack': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2978>,
#  'sugary': <gensim.models.keyedvectors.Vocab at 0x7f0d754e29b0>,
#  'excellent': <gensim.models.keyedvectors.Vocab at 0x7f0d754e29e8>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2a20>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2a58>,
#  'fan': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2a90>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2ac8>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2b00>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2b38>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2b70>,
#  'latte': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2ba8>,
#  'shop': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2be0>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2c18>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2c50>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2c88>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2cc0>,
#  'prepare': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2cf8>,
#  'cappuccino': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2d30>,
#  'minute': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2d68>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2da0>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2dd8>,
#  'dolce': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2e10>,
#  'gusto': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2e48>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2e80>,
#  'mccann': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2eb8>,
#  'instant': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2ef0>,
#  'oatmeal': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2f28>,
#  'scrape': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2f60>,
#  'escape': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2f98>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x7f0d754e2fd0>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6048>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6080>,
#  'stovetop': <gensim.models.keyedvectors.Vocab at 0x7f0d754e60b8>,
#  'preparation': <gensim.models.keyedvectors.Vocab at 0x7f0d754e60f0>,
#  'organic': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6128>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6160>,
#  'variety': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6198>,
#  'microwave': <gensim.models.keyedvectors.Vocab at 0x7f0d754e61d0>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6208>,
#  'boiling': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6240>,
#  'convenient': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6278>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x7f0d754e62b0>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x7f0d754e62e8>,
#  'cane': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6320>,
#  'fructose': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6358>,
#  'corn': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6390>,
#  'syrup': <gensim.models.keyedvectors.Vocab at 0x7f0d754e63c8>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6400>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6438>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6470>,
#  'harmful': <gensim.models.keyedvectors.Vocab at 0x7f0d754e64a8>,
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x7f0d754e64e0>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6518>,
#  'thickener': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6550>,
#  'oats': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6588>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x7f0d754e65c0>,
#  'creamy': <gensim.models.keyedvectors.Vocab at 0x7f0d754e65f8>,
#  'guar': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6630>,
#  'gum': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6668>,
#  'convenience': <gensim.models.keyedvectors.Vocab at 0x7f0d754e66a0>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7f0d754e66d8>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6710>,
#  'gluey': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6748>,
#  'sweetness': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6780>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x7f0d754e67b8>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7f0d754e67f0>,
#  'cold': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6828>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6860>,
#  'steel': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6898>,
#  'cinnamon': <gensim.models.keyedvectors.Vocab at 0x7f0d754e68d0>,
#  'maple': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6908>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6940>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6978>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7f0d754e69b0>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x7f0d754e69e8>,
#  'soggy': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6a20>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6a58>,
#  'texture': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6a90>,
#  'oat': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6ac8>,
#  'meal': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6b00>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6b38>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6b70>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6ba8>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6be0>,
#  'irish': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6c18>,
#  'apples': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6c50>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6c88>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6cc0>,
#  'hardy': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6cf8>,
#  'folk': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6d30>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6d68>,
#  'bariatric': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6da0>,
#  'surgery': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6dd8>,
#  'palatable': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6e10>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6e48>,
#  'digestible': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6e80>,
#  'fiber': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6eb8>,
#  'bloat': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6ef0>,
#  'celiac': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6f28>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6f60>,
#  'lifesaver': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6f98>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7f0d754e6fd0>,
#  'grocery': <gensim.models.keyedvectors.Vocab at 0x7f0d75469048>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x7f0d75469080>,
#  'cup': <gensim.models.keyedvectors.Vocab at 0x7f0d754690b8>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x7f0d754690f0>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x7f0d75469128>,
#  'milk': <gensim.models.keyedvectors.Vocab at 0x7f0d75469160>,
#  'kroger': <gensim.models.keyedvectors.Vocab at 0x7f0d75469198>,
#  'mmm': <gensim.models.keyedvectors.Vocab at 0x7f0d754691d0>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x7f0d75469208>,
#  'nate': <gensim.models.keyedvectors.Vocab at 0x7f0d75469240>,
#  'storage': <gensim.models.keyedvectors.Vocab at 0x7f0d75469278>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x7f0d754692b0>,
#  'packet': <gensim.models.keyedvectors.Vocab at 0x7f0d754692e8>,
#  'mccanns': <gensim.models.keyedvectors.Vocab at 0x7f0d75469320>,
#  'suggest': <gensim.models.keyedvectors.Vocab at 0x7f0d75469358>,
#  'stash': <gensim.models.keyedvectors.Vocab at 0x7f0d75469390>,
#  'dose': <gensim.models.keyedvectors.Vocab at 0x7f0d754693c8>,
#  'chance': <gensim.models.keyedvectors.Vocab at 0x7f0d75469400>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f0d75469438>,
#  'cinn': <gensim.models.keyedvectors.Vocab at 0x7f0d75469470>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7f0d754694a8>,
#  'slice': <gensim.models.keyedvectors.Vocab at 0x7f0d754694e0>,
#  'toast': <gensim.models.keyedvectors.Vocab at 0x7f0d75469518>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x7f0d75469550>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f0d75469588>,
#  'jerry': <gensim.models.keyedvectors.Vocab at 0x7f0d754695c0>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x7f0d754695f8>,
#  'reccomende': <gensim.models.keyedvectors.Vocab at 0x7f0d75469630>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7f0d75469668>,
#  'cent': <gensim.models.keyedvectors.Vocab at 0x7f0d754696a0>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7f0d754696d8>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x7f0d75469710>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x7f0d75469748>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x7f0d75469780>,
#  'tired': <gensim.models.keyedvectors.Vocab at 0x7f0d754697b8>,
#  'ole': <gensim.models.keyedvectors.Vocab at 0x7f0d754697f0>,
#  'boil': <gensim.models.keyedvectors.Vocab at 0x7f0d75469828>,
#  'pot': <gensim.models.keyedvectors.Vocab at 0x7f0d75469860>,
#  'pour': <gensim.models.keyedvectors.Vocab at 0x7f0d75469898>,
#  'expand': <gensim.models.keyedvectors.Vocab at 0x7f0d754698d0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f0d75469908>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7f0d75469940>,
#  'cheap': <gensim.models.keyedvectors.Vocab at 0x7f0d75469978>,
#  'connoisseur': <gensim.models.keyedvectors.Vocab at 0x7f0d754699b0>,
#  'raw': <gensim.models.keyedvectors.Vocab at 0x7f0d754699e8>,
#  'pellet': <gensim.models.keyedvectors.Vocab at 0x7f0d75469a20>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f0d75469a58>,
#  'cook': <gensim.models.keyedvectors.Vocab at 0x7f0d75469a90>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7f0d75469ac8>,
#  'sloth': <gensim.models.keyedvectors.Vocab at 0x7f0d75469b00>,
#  'beauty': <gensim.models.keyedvectors.Vocab at 0x7f0d75469b38>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x7f0d75469b70>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x7f0d75469ba8>,
#  'explore': <gensim.models.keyedvectors.Vocab at 0x7f0d75469be0>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f0d75469c18>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7f0d75469c50>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x7f0d75469c88>,
#  'personally': <gensim.models.keyedvectors.Vocab at 0x7f0d75469cc0>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7f0d75469cf8>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x7f0d75469d30>,
#  'tend': <gensim.models.keyedvectors.Vocab at 0x7f0d75469d68>,
#  'liquidy': <gensim.models.keyedvectors.Vocab at 0x7f0d75469da0>,
#  'experiment': <gensim.models.keyedvectors.Vocab at 0x7f0d75469dd8>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x7f0d75469e10>,
#  'handle': <gensim.models.keyedvectors.Vocab at 0x7f0d75469e48>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f0d75469e80>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x7f0d75469eb8>,
#  'offering': <gensim.models.keyedvectors.Vocab at 0x7f0d75469ef0>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f0d75469f28>,
#  'count': <gensim.models.keyedvectors.Vocab at 0x7f0d75469f60>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7f0d75469f98>,
#  'eater': <gensim.models.keyedvectors.Vocab at 0x7f0d75469fd0>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c048>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c080>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c0b8>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c0f0>,
#  'overly': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c128>,
#  'breakfast': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c160>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c198>,
#  'regularly': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c1d0>,
#  'wholesome': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c208>,
#  'supermarket': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c240>,
#  'somewhat': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c278>,
#  'mushy': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c2b0>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c2e8>,
#  'muster': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c320>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c358>,
#  'direction': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c390>,
#  'soupy': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c3c8>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c400>,
#  'ok': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c438>,
#  'satisfy': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c470>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c4a8>,
#  'carbs': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c4e0>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c518>,
#  'quaker': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c550>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c588>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c5c0>,
#  'bloody': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c5f8>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c630>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c668>,
#  'seller': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c6a0>,
#  'advertising': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c6d8>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c710>,
#  'lol': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c748>,
#  'buddy': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c780>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c7b8>,
#  'mouth': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c7f0>,
#  'forever': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c828>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c860>,
#  'temp': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c898>,
#  'vermont': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c8d0>,
#  'weston': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c908>,
#  'jaw': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c940>,
#  'harp': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c978>,
#  'cranberry': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c9b0>,
#  'horseradish': <gensim.models.keyedvectors.Vocab at 0x7f0d7546c9e8>,
#  'bean': <gensim.models.keyedvectors.Vocab at 0x7f0d7546ca20>,
#  'salsa': <gensim.models.keyedvectors.Vocab at 0x7f0d7546ca58>,
#  'cider': <gensim.models.keyedvectors.Vocab at 0x7f0d7546ca90>,
#  'jelly': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cac8>,
#  'newton': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cb00>,
#  'cradle': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cb38>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cb70>,
#  'motion': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cba8>,
#  'staple': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cbe0>,
#  'ass': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cc18>,
#  'kickin': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cc50>,
#  'peanuts': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cc88>,
#  'activate': <gensim.models.keyedvectors.Vocab at 0x7f0d7546ccc0>,
#  'perspiration': <gensim.models.keyedvectors.Vocab at 0x7f0d7546ccf8>,
#  'gland': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cd30>,
#  'ear': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cd68>,
#  'arm': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cda0>,
#  'beverage': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cdd8>,
#  'advertise': <gensim.models.keyedvectors.Vocab at 0x7f0d7546ce10>,
#  'glass': <gensim.models.keyedvectors.Vocab at 0x7f0d7546ce48>,
#  'kleenex': <gensim.models.keyedvectors.Vocab at 0x7f0d7546ce80>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x7f0d7546ceb8>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cef0>,
#  'ordinary': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cf28>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cf60>,
#  'suspect': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cf98>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f0d7546cfd0>,
#  'goody': <gensim.models.keyedvectors.Vocab at 0x7f0d75470048>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x7f0d75470080>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x7f0d754700b8>,
#  'colleague': <gensim.models.keyedvectors.Vocab at 0x7f0d754700f0>,
#  'greg': <gensim.models.keyedvectors.Vocab at 0x7f0d75470128>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f0d75470160>,
#  'opportunity': <gensim.models.keyedvectors.Vocab at 0x7f0d75470198>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x7f0d754701d0>,
#  'planters': <gensim.models.keyedvectors.Vocab at 0x7f0d75470208>,
#  'crying': <gensim.models.keyedvectors.Vocab at 0x7f0d75470240>,
#  'shake': <gensim.models.keyedvectors.Vocab at 0x7f0d75470278>,
#  'ensure': <gensim.models.keyedvectors.Vocab at 0x7f0d754702b0>,
#  'spice': <gensim.models.keyedvectors.Vocab at 0x7f0d754702e8>,
#  'evenly': <gensim.models.keyedvectors.Vocab at 0x7f0d75470320>,
#  'distribute': <gensim.models.keyedvectors.Vocab at 0x7f0d75470358>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f0d75470390>,
#  'wash': <gensim.models.keyedvectors.Vocab at 0x7f0d754703c8>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7f0d75470400>,
#  'consumption': <gensim.models.keyedvectors.Vocab at 0x7f0d75470438>,
#  'deliberately': <gensim.models.keyedvectors.Vocab at 0x7f0d75470470>,
#  'christmas': <gensim.models.keyedvectors.Vocab at 0x7f0d754704a8>,
#  'insulted': <gensim.models.keyedvectors.Vocab at 0x7f0d754704e0>,
#  'spicy': <gensim.models.keyedvectors.Vocab at 0x7f0d75470518>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x7f0d75470550>,
#  'texas': <gensim.models.keyedvectors.Vocab at 0x7f0d75470588>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x7f0d754705c0>,
#  'habanero': <gensim.models.keyedvectors.Vocab at 0x7f0d754705f8>,
#  'notch': <gensim.models.keyedvectors.Vocab at 0x7f0d75470630>,
#  'roast': <gensim.models.keyedvectors.Vocab at 0x7f0d75470668>,
#  'stove': <gensim.models.keyedvectors.Vocab at 0x7f0d754706a0>,
#  'popcorn': <gensim.models.keyedvectors.Vocab at 0x7f0d754706d8>,
#  'popper': <gensim.models.keyedvectors.Vocab at 0x7f0d75470710>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x7f0d75470748>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7f0d75470780>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x7f0d754707b8>,
#  'mexican': <gensim.models.keyedvectors.Vocab at 0x7f0d754707f0>,
#  'altura': <gensim.models.keyedvectors.Vocab at 0x7f0d75470828>,
#  'suit': <gensim.models.keyedvectors.Vocab at 0x7f0d75470860>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x7f0d75470898>,
#  'crack': <gensim.models.keyedvectors.Vocab at 0x7f0d754708d0>,
#  'distinct': <gensim.models.keyedvectors.Vocab at 0x7f0d75470908>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x7f0d75470940>,
#  'slightly': <gensim.models.keyedvectors.Vocab at 0x7f0d75470978>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x7f0d754709b0>,
#  'aroma': <gensim.models.keyedvectors.Vocab at 0x7f0d754709e8>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f0d75470a20>,
#  'persistent': <gensim.models.keyedvectors.Vocab at 0x7f0d75470a58>,
#  'smooth': <gensim.models.keyedvectors.Vocab at 0x7f0d75470a90>,
#  'velvety': <gensim.models.keyedvectors.Vocab at 0x7f0d75470ac8>,
#  'lively': <gensim.models.keyedvectors.Vocab at 0x7f0d75470b00>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f0d75470b38>,
#  'cast': <gensim.models.keyedvectors.Vocab at 0x7f0d75470b70>,
#  'iron': <gensim.models.keyedvectors.Vocab at 0x7f0d75470ba8>,
#  'pan': <gensim.models.keyedvectors.Vocab at 0x7f0d75470be0>,
#  'grill': <gensim.models.keyedvectors.Vocab at 0x7f0d75470c18>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x7f0d75470c50>,
#  'importantly': <gensim.models.keyedvectors.Vocab at 0x7f0d75470c88>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x7f0d75470cc0>,
#  'aftertaste': <gensim.models.keyedvectors.Vocab at 0x7f0d75470cf8>,
#  'numerous': <gensim.models.keyedvectors.Vocab at 0x7f0d75470d30>,
#  'occasion': <gensim.models.keyedvectors.Vocab at 0x7f0d75470d68>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x7f0d75470da0>,
#  'awesome': <gensim.models.keyedvectors.Vocab at 0x7f0d75470dd8>,
#  'halloween': <gensim.models.keyedvectors.Vocab at 0x7f0d75470e10>,
#  'indicate': <gensim.models.keyedvectors.Vocab at 0x7f0d75470e48>,
#  'trick': <gensim.models.keyedvectors.Vocab at 0x7f0d75470e80>,
#  'treater': <gensim.models.keyedvectors.Vocab at 0x7f0d75470eb8>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7f0d75470ef0>,
#  'kit': <gensim.models.keyedvectors.Vocab at 0x7f0d75470f28>,
#  'kat': <gensim.models.keyedvectors.Vocab at 0x7f0d75470f60>,
#  'reeses': <gensim.models.keyedvectors.Vocab at 0x7f0d75470f98>,
#  'plenty': <gensim.models.keyedvectors.Vocab at 0x7f0d75470fd0>,
#  'ship': <gensim.models.keyedvectors.Vocab at 0x7f0d75473048>,
#  'promptly': <gensim.models.keyedvectors.Vocab at 0x7f0d75473080>,
#  'neighborhood': <gensim.models.keyedvectors.Vocab at 0x7f0d754730b8>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7f0d754730f0>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x7f0d75473128>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x7f0d75473160>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x7f0d75473198>,
#  'compete': <gensim.models.keyedvectors.Vocab at 0x7f0d754731d0>,
#  'pill': <gensim.models.keyedvectors.Vocab at 0x7f0d75473208>,
#  'powder': <gensim.models.keyedvectors.Vocab at 0x7f0d75473240>,
#  'desert': <gensim.models.keyedvectors.Vocab at 0x7f0d75473278>,
#  'ride': <gensim.models.keyedvectors.Vocab at 0x7f0d754732b0>,
#  'dirt': <gensim.models.keyedvectors.Vocab at 0x7f0d754732e8>,
#  'bike': <gensim.models.keyedvectors.Vocab at 0x7f0d75473320>,
#  'camelbak': <gensim.models.keyedvectors.Vocab at 0x7f0d75473358>,
#  'heavily': <gensim.models.keyedvectors.Vocab at 0x7f0d75473390>,
#  'lace': <gensim.models.keyedvectors.Vocab at 0x7f0d754733c8>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7f0d75473400>,
#  'cramp': <gensim.models.keyedvectors.Vocab at 0x7f0d75473438>,
#  'mile': <gensim.models.keyedvectors.Vocab at 0x7f0d75473470>,
#  'race': <gensim.models.keyedvectors.Vocab at 0x7f0d754734a8>,
#  'buggy': <gensim.models.keyedvectors.Vocab at 0x7f0d754734e0>,
#  'fizz': <gensim.models.keyedvectors.Vocab at 0x7f0d75473518>,
#  'firstly': <gensim.models.keyedvectors.Vocab at 0x7f0d75473550>,
#  'hammer': <gensim.models.keyedvectors.Vocab at 0x7f0d75473588>,
#  'endurance': <gensim.models.keyedvectors.Vocab at 0x7f0d754735c0>,
#  'athlete': <gensim.models.keyedvectors.Vocab at 0x7f0d754735f8>,
#  'tablet': <gensim.models.keyedvectors.Vocab at 0x7f0d75473630>,
#  'dissovle': <gensim.models.keyedvectors.Vocab at 0x7f0d75473668>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x7f0d754736a0>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x7f0d754736d8>,
#  'starve': <gensim.models.keyedvectors.Vocab at 0x7f0d75473710>,
#  'hydration': <gensim.models.keyedvectors.Vocab at 0x7f0d75473748>,
#  'electrolyte': <gensim.models.keyedvectors.Vocab at 0x7f0d75473780>,
#  'salty': <gensim.models.keyedvectors.Vocab at 0x7f0d754737b8>,
#  'refresh': <gensim.models.keyedvectors.Vocab at 0x7f0d754737f0>,
#  'lemon': <gensim.models.keyedvectors.Vocab at 0x7f0d75473828>,
#  'lime': <gensim.models.keyedvectors.Vocab at 0x7f0d75473860>,
#  'mango': <gensim.models.keyedvectors.Vocab at 0x7f0d75473898>,
#  'bottled': <gensim.models.keyedvectors.Vocab at 0x7f0d754738d0>,
#  'exercise': <gensim.models.keyedvectors.Vocab at 0x7f0d75473908>,
#  'chock': <gensim.models.keyedvectors.Vocab at 0x7f0d75473940>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x7f0d75473978>,
#  'grapefruit': <gensim.models.keyedvectors.Vocab at 0x7f0d754739b0>,
#  'slight': <gensim.models.keyedvectors.Vocab at 0x7f0d754739e8>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7f0d75473a20>,
#  'prevent': <gensim.models.keyedvectors.Vocab at 0x7f0d75473a58>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7f0d75473a90>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x7f0d75473ac8>,
#  'pop': <gensim.models.keyedvectors.Vocab at 0x7f0d75473b00>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7f0d75473b38>,
#  'carb': <gensim.models.keyedvectors.Vocab at 0x7f0d75473b70>,
#  'diet': <gensim.models.keyedvectors.Vocab at 0x7f0d75473ba8>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f0d75473be0>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7f0d75473c18>,
#  'cycle': <gensim.models.keyedvectors.Vocab at 0x7f0d75473c50>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f0d75473c88>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7f0d75473cc0>,
#  'arrhythmia': <gensim.models.keyedvectors.Vocab at 0x7f0d75473cf8>,
# ...
#  'superbly': <gensim.models.keyedvectors.Vocab at 0x7f0d754770b8>,
#  'formulate': <gensim.models.keyedvectors.Vocab at 0x7f0d754770f0>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x7f0d75477128>,
#  'consume': <gensim.models.keyedvectors.Vocab at 0x7f0d75477160>,
#  'nutrition': <gensim.models.keyedvectors.Vocab at 0x7f0d75477198>,
#  'decade': <gensim.models.keyedvectors.Vocab at 0x7f0d754771d0>,
#  'appealing': <gensim.models.keyedvectors.Vocab at 0x7f0d75477208>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x7f0d75477240>,
#  'sip': <gensim.models.keyedvectors.Vocab at 0x7f0d75477278>,
#  'impulsive': <gensim.models.keyedvectors.Vocab at 0x7f0d754772b0>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7f0d754772e8>,
#  'baby': <gensim.models.keyedvectors.Vocab at 0x7f0d75477320>,
#  'retrospect': <gensim.models.keyedvectors.Vocab at 0x7f0d75477358>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x7f0d75477390>,
#  'esp': <gensim.models.keyedvectors.Vocab at 0x7f0d754773c8>,
#  'shipping': <gensim.models.keyedvectors.Vocab at 0x7f0d75477400>,
#  'sooooo': <gensim.models.keyedvectors.Vocab at 0x7f0d75477438>,
#  'deliscious': <gensim.models.keyedvectors.Vocab at 0x7f0d75477470>,
#  '-pron-': <gensim.models.keyedvectors.Vocab at 0x7f0d754774a8>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7f0d754774e0>,
#  'pds': <gensim.models.keyedvectors.Vocab at 0x7f0d75477518>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x7f0d75477550>,
#  'albanese': <gensim.models.keyedvectors.Vocab at 0x7f0d75477588>,
#  'gummi': <gensim.models.keyedvectors.Vocab at 0x7f0d754775c0>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x7f0d754775f8>,
#  'ring': <gensim.models.keyedvectors.Vocab at 0x7f0d75477630>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f0d75477668>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7f0d754776a0>,
#  'snake': <gensim.models.keyedvectors.Vocab at 0x7f0d754776d8>,
#  'ball': <gensim.models.keyedvectors.Vocab at 0x7f0d75477710>,
#  'worm': <gensim.models.keyedvectors.Vocab at 0x7f0d75477748>,
#  'lb': <gensim.models.keyedvectors.Vocab at 0x7f0d75477780>,
#  'twin': <gensim.models.keyedvectors.Vocab at 0x7f0d754777b8>,
#  'scream': <gensim.models.keyedvectors.Vocab at 0x7f0d754777f0>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7f0d75477828>,
#  'concerned': <gensim.models.keyedvectors.Vocab at 0x7f0d75477860>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x7f0d75477898>,
#  'friggin': <gensim.models.keyedvectors.Vocab at 0x7f0d754778d0>,
#  'gummy': <gensim.models.keyedvectors.Vocab at 0x7f0d75477908>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f0d75477940>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x7f0d75477978>,
#  'sour': <gensim.models.keyedvectors.Vocab at 0x7f0d754779b0>,
#  'kick': <gensim.models.keyedvectors.Vocab at 0x7f0d754779e8>,
#  'opinion': <gensim.models.keyedvectors.Vocab at 0x7f0d75477a20>,
#  'popsicles': <gensim.models.keyedvectors.Vocab at 0x7f0d75477a58>,
#  'popsicle': <gensim.models.keyedvectors.Vocab at 0x7f0d75477a90>,
#  'frozen': <gensim.models.keyedvectors.Vocab at 0x7f0d75477ac8>,
#  'tart': <gensim.models.keyedvectors.Vocab at 0x7f0d75477b00>,
#  'directly': <gensim.models.keyedvectors.Vocab at 0x7f0d75477b38>,
#  'fantasicakes': <gensim.models.keyedvectors.Vocab at 0x7f0d75477b70>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x7f0d75477ba8>,
#  'dinner': <gensim.models.keyedvectors.Vocab at 0x7f0d75477be0>,
#  'host': <gensim.models.keyedvectors.Vocab at 0x7f0d75477c18>,
#  'intact': <gensim.models.keyedvectors.Vocab at 0x7f0d75477c50>,
#  'freeze': <gensim.models.keyedvectors.Vocab at 0x7f0d75477c88>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7f0d75477cc0>,
#  'pastry': <gensim.models.keyedvectors.Vocab at 0x7f0d75477cf8>,
#  'jam': <gensim.models.keyedvectors.Vocab at 0x7f0d75477d30>,
#  'guest': <gensim.models.keyedvectors.Vocab at 0x7f0d75477d68>,
#  'beware': <gensim.models.keyedvectors.Vocab at 0x7f0d75477da0>,
#  'sweetener': <gensim.models.keyedvectors.Vocab at 0x7f0d75477dd8>,
#  'everybody': <gensim.models.keyedvectors.Vocab at 0x7f0d75477e10>,
#  'maltitol': <gensim.models.keyedvectors.Vocab at 0x7f0d75477e48>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x7f0d75477e80>,
#  'undigestible': <gensim.models.keyedvectors.Vocab at 0x7f0d75477eb8>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x7f0d75477ef0>,
#  'unsuspecting': <gensim.models.keyedvectors.Vocab at 0x7f0d75477f28>,
#  'digest': <gensim.models.keyedvectors.Vocab at 0x7f0d75477f60>,
#  'intestinal': <gensim.models.keyedvectors.Vocab at 0x7f0d75477f98>,
#  'bloating': <gensim.models.keyedvectors.Vocab at 0x7f0d75477fd0>,
#  'massive': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b048>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b080>,
#  'nausea': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b0b8>,
#  'diarrhea': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b0f0>,
#  'headache': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b128>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b160>,
#  'lesson': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b198>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b1d0>,
#  'suzanne': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b208>,
#  'sommer': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b240>,
#  'nirvana': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b278>,
#  'bliss': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b2b0>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b2e8>,
#  'discomfort': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b320>,
#  'unlike': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b358>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b390>,
#  'balloon': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b3c8>,
#  'painful': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b400>,
#  'abdominal': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b438>,
#  'cramping': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b470>,
#  'symptom': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b4a8>,
#  'unpleasant': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b4e0>,
#  'calorie': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b518>,
#  'culprit': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b550>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b588>,
#  'hunch': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b5c0>,
#  'confirm': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b5f8>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b630>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b668>,
#  'possibly': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b6a0>,
#  'sugarfree': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b6d8>,
#  'sink': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b710>,
#  'asterisk': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b748>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b780>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b7b8>,
#  'goodness': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b7f0>,
#  'eaten': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b828>,
#  'duration': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b860>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b898>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b8d0>,
#  'tea': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b908>,
#  'brunch': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b940>,
#  'returnable': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b978>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b9b0>,
#  'buck': <gensim.models.keyedvectors.Vocab at 0x7f0d7547b9e8>,
#  'trail': <gensim.models.keyedvectors.Vocab at 0x7f0d7547ba20>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x7f0d7547ba58>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x7f0d7547ba90>,
#  'melted': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bac8>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bb00>,
#  'pantry': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bb38>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bb70>,
#  'temperature': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bba8>,
#  'gooey': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bbe0>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bc18>,
#  'hunk': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bc50>,
#  'grainy': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bc88>,
#  'melt': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bcc0>,
#  'solidify': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bcf8>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bd30>,
#  'reviewer': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bd68>,
#  'ordering': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bda0>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bdd8>,
#  'insulate': <gensim.models.keyedvectors.Vocab at 0x7f0d7547be10>,
#  'packaging': <gensim.models.keyedvectors.Vocab at 0x7f0d7547be48>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7f0d7547be80>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x7f0d7547beb8>,
#  'weather': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bef0>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bf28>,
#  'berry': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bf60>,
#  'winter': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bf98>,
#  'grant': <gensim.models.keyedvectors.Vocab at 0x7f0d7547bfd0>,
#  'crisp': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f048>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f080>,
#  'dad': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f0b8>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f0f0>,
#  'gift': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f128>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f160>,
#  'giant': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f198>,
#  'recipient': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f1d0>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f208>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f240>,
#  'molecular': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f278>,
#  'gastronomy': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f2b0>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f2e8>,
#  'scare': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f320>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f358>,
#  'blonde': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f390>,
#  'creamer': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f3c8>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f400>,
#  'hate': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f438>,
#  'manufacture': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f470>,
#  'cream': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f4a8>,
#  'stumble': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f4e0>,
#  'lowfat': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f518>,
#  'dissolve': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f550>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f588>,
#  'ratio': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f5c0>,
#  'heavy': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f5f8>,
#  'flavoring': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f630>,
#  'bough': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f668>,
#  'cocoa': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f6a0>,
#  'vanilla': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f6d8>,
#  'caster': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f710>,
#  'superfine': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f748>,
#  'batch': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f780>,
#  'nutmeg': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f7b8>,
#  'fake': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f7f0>,
#  'sweetner': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f828>,
#  'jar': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f860>,
#  'chopper': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f898>,
#  'processor': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f8d0>,
#  'blend': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f908>,
#  'settle': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f940>,
#  'storebought': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f978>,
#  'essential': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f9b0>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x7f0d7547f9e8>,
#  'orange': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fa20>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fa58>,
#  'housewarming': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fa90>,
#  'cooking': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fac8>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fb00>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fb38>,
#  'itching': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fb70>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fba8>,
#  'lamb': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fbe0>,
#  'rice': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fc18>,
#  'itchy': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fc50>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fc88>,
#  'duck': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fcc0>,
#  'potato': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fcf8>,
#  'significantly': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fd30>,
#  'itch': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fd68>,
#  'balance': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fda0>,
#  'boston': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fdd8>,
#  'severe': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fe10>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fe48>,
#  'jumping': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fe80>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x7f0d7547feb8>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7f0d7547fef0>,
#  'scratching': <gensim.models.keyedvectors.Vocab at 0x7f0d7547ff28>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7f0d7547ff60>,
#  'pet': <gensim.models.keyedvectors.Vocab at 0x7f0d7547ff98>,
#  'specifically': <gensim.models.keyedvectors.Vocab at 0x7f0d7547ffd0>,
#  'allergy': <gensim.models.keyedvectors.Vocab at 0x7f0d75482048>,
#  'tummy': <gensim.models.keyedvectors.Vocab at 0x7f0d75482080>,
#  'ton': <gensim.models.keyedvectors.Vocab at 0x7f0d754820b8>,
#  'environmental': <gensim.models.keyedvectors.Vocab at 0x7f0d754820f0>,
#  'prescription': <gensim.models.keyedvectors.Vocab at 0x7f0d75482128>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x7f0d75482160>,
#  'allergic': <gensim.models.keyedvectors.Vocab at 0x7f0d75482198>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x7f0d754821d0>,
#  'trigger': <gensim.models.keyedvectors.Vocab at 0x7f0d75482208>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x7f0d75482240>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x7f0d75482278>,
#  'shepherd': <gensim.models.keyedvectors.Vocab at 0x7f0d754822b0>,
#  'collie': <gensim.models.keyedvectors.Vocab at 0x7f0d754822e8>,
#  'ibs': <gensim.models.keyedvectors.Vocab at 0x7f0d75482320>,
#  'vet': <gensim.models.keyedvectors.Vocab at 0x7f0d75482358>,
#  'recipe': <gensim.models.keyedvectors.Vocab at 0x7f0d75482390>,
#  'jack': <gensim.models.keyedvectors.Vocab at 0x7f0d754823c8>,
#  'russell': <gensim.models.keyedvectors.Vocab at 0x7f0d75482400>,
#  'awful': <gensim.models.keyedvectors.Vocab at 0x7f0d75482438>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7f0d75482470>,
#  'normally': <gensim.models.keyedvectors.Vocab at 0x7f0d754824a8>,
#  'wet': <gensim.models.keyedvectors.Vocab at 0x7f0d754824e0>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x7f0d75482518>,
#  'bichon': <gensim.models.keyedvectors.Vocab at 0x7f0d75482550>,
#  'stomach': <gensim.models.keyedvectors.Vocab at 0x7f0d75482588>,
#  'breed': <gensim.models.keyedvectors.Vocab at 0x7f0d754825c0>,
#  'poop': <gensim.models.keyedvectors.Vocab at 0x7f0d754825f8>,
#  'consistency': <gensim.models.keyedvectors.Vocab at 0x7f0d75482630>,
#  'mom': <gensim.models.keyedvectors.Vocab at 0x7f0d75482668>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x7f0d754826a0>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x7f0d754826d8>,
#  ...}

# %%
modelo_w2v_sg['cheap']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-0.1259561 , -0.4343633 ,  0.11544825,  0.37036207,  0.02404923,
#         0.12771359, -0.11024404,  0.07505909,  0.00588032,  0.11527938,
#        -0.15609452,  0.23163009,  0.4501444 ,  0.44907334,  0.19261187,
#        -0.09032837,  0.03712239,  0.16728175,  0.12081986,  0.35452172,
#         0.03871497,  0.06429012,  0.3569138 ,  0.03053388, -0.1945995 ,
#        -0.24858478, -0.21007095, -0.01617339, -0.16569327,  0.12372867,
#         0.12434195,  0.18353032,  0.01307029,  0.12009319,  0.29589656,
#         0.23793861, -0.15751565,  0.13425985,  0.12706701, -0.08293684,
#        -0.22191533,  0.2917584 , -0.12052703, -0.09782092, -0.08856533,
#         0.2080423 , -0.0045195 ,  0.02030792,  0.19006802, -0.20325619,
#         0.22794808, -0.42969278, -0.13556704, -0.05725838,  0.16113901,
#        -0.16998972, -0.35072988, -0.04790407,  0.11391092,  0.20651056,
#         0.27056786, -0.36972976, -0.00334894, -0.24998936,  0.2361827 ,
#        -0.15815926,  0.14368317,  0.36902148,  0.16334164, -0.04074959,
#         0.44562647,  0.22789939,  0.37635016, -0.05822464,  0.12857781,
#         0.23637974, -0.05587693,  0.3242395 ,  0.36499166, -0.06121239,
#        -0.09668413, -0.08472195, -0.11574516,  0.02662748,  0.3298332 ,
#        -0.1342373 ,  0.26476577,  0.31837475,  0.2498701 ,  0.1946686 ,
#         0.12872344,  0.05210854,  0.1534165 ,  0.36685956,  0.11461826,
#        -0.13565633, -0.13955972, -0.26338413,  0.00535933,  0.13963035],
#       dtype=float32)
