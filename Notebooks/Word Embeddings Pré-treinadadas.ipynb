# %% [markdown]
# # Importações

# %%
#Importando o KeyedVectors do Gensim
from gensim.models import KeyedVectors

# %% [markdown]
# # Fazendo o Download das WordEmbeddings

# %%
# !wget 'http://143.107.183.175:22980/download.php?file=embeddings/word2vec/cbow_s50.zip'
# Out:
# --2020-11-13 23:16:25--  http://143.107.183.175:22980/download.php?file=embeddings/word2vec/cbow_s50.zip
# Connecting to 143.107.183.175:22980... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170360268 (162M) [application/octet-stream]
# Saving to: ‘download.php?file=embeddings%2Fword2vec%2Fcbow_s50.zip’
#
# download.php?file=e 100%[===================>] 162.47M  8.68MB/s    in 21s
#
# 2020-11-13 23:16:47 (7.64 MB/s) - ‘download.php?file=embeddings%2Fword2vec%2Fcbow_s50.zip’ saved [170360268/170360268]

# %%
# !ls
# Out:
# 'download.php?file=embeddings%2Fword2vec%2Fcbow_s50.zip'   drive   sample_data

# %%
# !mv 'download.php?file=embeddings%2Fword2vec%2Fcbow_s50.zip' cbow_50.zip

# %%
# !unzip cbow_50.zip
# Out:
# Archive:  cbow_50.zip
#   inflating: cbow_s50.txt

# %% [markdown]
# # Carregando as word embeddings

# %%
modelo_wv = KeyedVectors.load_word2vec_format('/content/drive/My Drive/Datasets/Texts/cbow_s300.txt')

# %% [markdown]
# # Usando o modelo

# %%
modelo_wv.most_similar('computador')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('aplicativo', 0.582740306854248),
#  ('microcomputador', 0.5719903111457825),
#  ('antivírus', 0.5687523484230042),
#  ('telemóvel', 0.5623498558998108),
#  ('laptop', 0.562114953994751),
#  ('adaptador', 0.5598054528236389),
#  ('aparelho', 0.5597076416015625),
#  ('modem', 0.5581312775611877),
#  ('monitor', 0.5575480461120605),
#  ('chip', 0.5572286248207092)]

# %%
modelo_wv.most_similar('carro')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('veículo', 0.8137416839599609),
#  ('caminhão', 0.7600934505462646),
#  ('jipe', 0.680985689163208),
#  ('camião', 0.6723827719688416),
#  ('furgão', 0.6717828512191772),
#  ('veã\xadculo', 0.6359531879425049),
#  ('caminhã£o', 0.620665967464447),
#  ('avião', 0.610375165939331),
#  ('táxi', 0.60887610912323),
#  ('automóvel', 0.6054151058197021)]

# %%
modelo_wv.most_similar('automóvel')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('carro', 0.6054151058197021),
#  ('camião', 0.5798291563987732),
#  ('veículo', 0.5736527442932129),
#  ('autocarro', 0.5109732151031494),
#  ('jipe', 0.4992576539516449),
#  ('caminhão', 0.49036383628845215),
#  ('avião', 0.4787251949310303),
#  ('motociclo', 0.46653059124946594),
#  ('ultraleve', 0.4578385353088379),
#  ('barco', 0.4556341767311096)]

# %%
modelo_wv.most_similar(positive=['tecnologia','telefone'])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('telegrafia', 0.48593103885650635),
#  ('telemóvel', 0.45492956042289734),
#  ('computador', 0.44330695271492004),
#  ('informática', 0.4276118874549866),
#  ('aplicativo', 0.4261496663093567),
#  ('tec-nologia', 0.42611628770828247),
#  ('telefonia', 0.422924280166626),
#  ('modem', 0.4215902090072632),
#  ('telefones', 0.4214838445186615),
#  ('telégrafo', 0.4205682575702667)]

# %%
modelo_wv.most_similar('presidente')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('vice-presidente', 0.7934563755989075),
#  ('ex-presidente', 0.7456357479095459),
#  ('presi-dente', 0.6932410597801208),
#  ('pre-sidente', 0.6644260287284851),
#  ('secretário-geral', 0.6364240646362305),
#  ('primeiro-secretário', 0.622976541519165),
#  ('diretor-geral', 0.6131710410118103),
#  ('diretor-presidente', 0.5877721309661865),
#  ('consultor-geral', 0.5869454145431519),
#  ('presiden-te', 0.5818982720375061)]

# %%
modelo_wv.get_vector('presidente')
# Out:
# array([ 3.11052e-01, -3.15930e-02,  2.25126e-01,  2.59639e-01,
#         2.86357e-01,  1.23475e-01,  1.88800e-03, -2.02394e-01,
#         5.56200e-03,  1.49868e-01, -4.84070e-02,  1.28759e-01,
#        -1.04967e-01, -3.07466e-01, -1.27674e-01, -2.91580e-02,
#        -5.11910e-02,  2.51107e-01, -2.15141e-01,  1.53660e-01,
#        -2.13328e-01, -2.46830e-02,  1.46720e-01, -9.61810e-02,
#         1.93689e-01,  1.60763e-01,  3.48293e-01,  2.05784e-01,
#        -2.68860e-02, -1.27080e-01, -9.73500e-03, -3.58380e-02,
#        -2.54900e-02, -3.13166e-01, -5.44000e-04, -1.59497e-01,
#         3.22390e-01, -8.69250e-02, -2.66975e-01, -1.33000e-02,
#         3.05290e-02, -1.60271e-01, -1.12474e-01,  9.05420e-02,
#        -2.02130e-02, -1.46053e-01,  8.95100e-02,  1.82136e-01,
#        -1.88984e-01, -5.82000e-03,  1.23905e-01,  2.33062e-01,
#        -3.05783e-01,  1.34332e-01, -2.38088e-01,  2.77867e-01,
#        -1.79164e-01,  1.06049e-01,  8.31070e-02, -3.57580e-02,
# ...
