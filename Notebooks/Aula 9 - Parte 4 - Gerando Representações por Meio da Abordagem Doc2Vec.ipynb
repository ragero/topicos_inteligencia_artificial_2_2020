# %% [markdown]
# # Importações

# %%
# Carregar e visualizar os dados
import pandas as pd
import numpy as np

#Biblioteca para gerar e manipular as word embeddings
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

#Biblioteca para preprocessar os textos 
import spacy

#O tqdm é utilizado para exibir uma barra de progresso
#Os demais comandos são utilizados para o correto funcionamento no Colab
from tqdm import tqdm
from IPython import get_ipython
def tqdm_clear(*args, **kwargs):
    getattr(tqdm, '_instances', {}).clear()

#Importando bibliotecas do ScikitLearn para: 
# - Faze a divisão entre treino e teste
from sklearn.model_selection import train_test_split
# - Importanto um modelo de classificação SVC (Support Vector Classifier)
from sklearn.svm import SVC
# - Importante a função para avaliar o resultado da classificação
from sklearn.metrics import f1_score

# %% [markdown]
# # Carregando o Dataset

# %%
df = pd.read_csv('/content/drive/My Drive/Datasets/Texts/CSTR.csv')

# %%
df
# Out:
#     file_name  ...                    class
# 0     126.txt  ...  ArtificiallIntelligence
# 1       5.txt  ...  ArtificiallIntelligence
# 2      48.txt  ...  ArtificiallIntelligence
# 3      81.txt  ...  ArtificiallIntelligence
# 4      25.txt  ...  ArtificiallIntelligence
# ..        ...  ...                      ...
# 294    39.txt  ...                   Theory
# 295     5.txt  ...                   Theory
# 296    28.txt  ...                   Theory
# 297    27.txt  ...                   Theory
# 298     4.txt  ...                   Theory
#
# [299 rows x 3 columns]

# %%
#Dividindo a coleção entre treino e teste
df_treino, df_teste = train_test_split(df, test_size=0.3, stratify=df['class'])

# %% [markdown]
# # Pré-processamento dos Textos

# %%
# Initializando o spacy, porém, desabilitando recursos que não iremos utilizar
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
# Preprocessamento dos textos
def preprocessamento (texto): 
  final_tokens = []
  doc = nlp(texto)
  for token in doc:
    if(token.is_alpha and not token.is_stop):
          final_tokens.append(token.lemma_.lower())
      
  return final_tokens

# %%
# Retornando um objeto TaggedDocument 
# O objeto TaggedDocument contém os tokens (words) e um identificador para os documentos (tags)
def tagged_data(texts): 
  return [TaggedDocument(words=preprocessamento(text), tags=[str(i)]) for i, text in enumerate(texts)]

# %%
# Construindo os vetores de treino
# Utiliza-se o model.docvecs[(string da tag)] para retornar um vetor de um documento
def constuir_vetores_treino(model, tagged_data, num_dim):
  matrix = np.zeros((len(tagged_data),num_dim))
  for i in range(len(tagged_data)):
    matrix[i] = model.docvecs[tagged_data[i][1][0]]
  return matrix

# %%
# Construindo os vetores dos novos documentos (teste)
# Utiliza-se a função infer_vector() e passasse uma lista com as palavras de um documento
def constuir_vetores_teste(model, tagged_data, num_dim):
  matrix = np.zeros((len(tagged_data),num_dim))
  for i in range(len(tagged_data)):
    matrix[i] = model.infer_vector(tagged_data[i][0])
  return matrix

# %% [markdown]
# #Gerando a Representação do Conjunto de Treino

# %%
#Definindo o numero de dimesões
num_dim = 100

# %%
#TaggedDocument é a estrutura necessária para o treinamento do modelo Doc2Vec
tagged_treino = tagged_data(df_treino['text'])

# %%
tagged_treino
# Out:
# [TaggedDocument(words=['order', 'understand', 'natural', 'language', 'necessary', 'understand', 'intention', 'utterance', 'speak', 'model', 'dialogue', 'collaboration', 'agent', 'communicative', 'intention', 'see', 'agent', 'try', 'affect', 'collaboration', 'previous', 'work', 'intention', 'recognition', 'approach', 'dialogue', 'focus', 'small', 'subset', 'agent', 'collaboration', 'paradigm', 'master', 'slave', 'unable', 'account', 'dialogue', 'paradigm', 'mix', 'initiative', 'collaboration', 'previous', 'work', 'model', 'dialogue', 'agent', 'plan', 'dialogue', 'agent', 'act', 'restrict', 'dialogue', 'model', 'coverage', 'case', 'model', 'dialogue', 'collaboration', 'act', 'planning', 'occur', 'paper', 'present', 'collaborative', 'problem', 'solve', 'model', 'dialogue', 'model', 'able', 'account', 'wide', 'array', 'dialogue', 'previous', 'model', 'cover', 'cover', 'spectrum', 'collaboration', 'paradigm', 'master', 'slave', 'mix', 'initiative', 'dialogue', 'interleave', 'acting', 'planning', 'take', 'place', 'propose', 'future', 'research', 'complete', 'model', 'build', 'domain', 'independent', 'intention', 'recognition', 'system', 'base', 'use', 'trips', 'dialogue', 'system'], tags=['0']),
#  TaggedDocument(words=['prove', 'distributional', 'problem', 'solvable', 'polynomial', 'time', 'average', 'respect', 'uniform', 'distribution', 'frequently', 'self', 'knowingly', 'correct', 'polynomial', 'time', 'algorithm', 'study', 'feature', 'probability', 'weight', 'correctness', 'respect', 'generalization', 'procaccia', 'rosenschein', 'junta', 'distribution'], tags=['1']),
#  TaggedDocument(words=['thesis', 'present', 'approach', 'understanding', 'extend', 'robotic', 'motor', 'control', 'integrate', 'human', 'guidance', 'focus', 'dexterous', 'manipulation', 'utah', 'mit', 'robot', 'hand', 'idea', 'apply', 'robotic', 'platform', 'teleassistance', 'novel', 'method', 'human', 'robot', 'interaction', 'human', 'operator', 'use', 'gestural', 'sign', 'language', 'guide', 'autonomous', 'robot', 'give', 'task', 'operator', 'wear', 'glove', 'measure', 'finger', 'joint', 'angle', 'relay', 'sign', 'language', 'sign', 'serve', 'orient', 'robot', 'task', 'action', 'sequence', 'indicate', 'perceptual', 'sub', 'goal', 'relative', 'spatial', 'basis', 'teleassistance', 'merge', 'robotic', 'servo', 'loop', 'human', 'cognition', 'alleviate', 'limitation', 'robot', 'autonomy', 'human', 'control', 'operator', 'gesture', 'deictic', 'greek', 'deiktikos', 'meaning', 'point', 'showing', 'circumscribe', 'possible', 'interpretation', 'perceptual', 'feedback', 'current', 'context', 'allow', 'autonomous', 'routine', 'perform', 'computational', 'economy', 'dependence', 'detailed', 'task', 'model', 'conversely', 'use', 'symbolic', 'gesture', 'permit', 'operator', 'guide', 'robot', 'strategically', 'problem', 'inherent', 'literal', 'master', 'slave', 'teleoperation', 'include', 'non', 'anthropomorphic', 'mapping', 'poor', 'feedback', 'reliance', 'tight', 'communication', 'loop', 'development', 'teleassistance', 'stem', 'analysis', 'autonomous', 'control', 'light', 'recent', 'advance', 'manipulator', 'technology', 'work', 'present', 'qualitative', 'context', 'sensitive', 'control', 'strategy', 'exploit', 'degree', 'freedom', 'compliance', 'dexterous', 'manipulator', 'qualitative', 'strategy', 'govern', 'underlying', 'autonomous', 'routine', 'teleassistance'], tags=['2']),
#  TaggedDocument(words=['limit', 'memory', 'available', 'program', 'hamstre', 'performance', 'garbage', 'collect', 'environment', 'allow', 'large', 'heap', 'size', 'detrimental', 'garbage', 'collection', 'occasionally', 'access', 'entire', 'heap', 'have', 'significant', 'virtual', 'memory', 'expensive', 'determine', 'appropriate', 'size', 'program', 'heap', 'important', 'difficult', 'light', 'virtual', 'machine', 'operating', 'system', 'level', 'multi', 'programming', 'program', 'run', 'present', 'model', 'program', 'memory', 'usage', 'effective', 'multi', 'programming', 'likely', 'addition', 'present', 'automate', 'system', 'add', 'control', 'program', 'level', 'allow', 'runtime', 'adaptation', 'program', 'heap', 'size', 'process', 'fully', 'automatic', 'require', 'extra', 'coding', 'programmer', 'discuss', 'adaptive', 'scheme', 'act', 'independently', 'perform', 'competitively', 'system', 'behave', 'politely', 'multi', 'programmed', 'environment', 'second', 'scheme', 'explicitly', 'cooperate', 'multiple', 'instance', 'run', 'scheme', 'evaluate', 'term', 'response', 'time', 'throughput', 'fairness'], tags=['3']),
#  TaggedDocument(words=['find', 'lineal', 'feature', 'image', 'important', 'step', 'object', 'recognition', 'scene', 'analysis', 'procedure', 'previous', 'feature', 'extraction', 'algorithm', 'exhibit', 'poor', 'parallel', 'performance', 'feature', 'extend', 'large', 'area', 'data', 'set', 'paper', 'describe', 'parallel', 'method', 'extract', 'lineal', 'feature', 'base', 'earlier', 'sequential', 'algorithm', 'stick', 'grow', 'new', 'method', 'produce', 'result', 'qualitatively', 'similar', 'sequential', 'method', 'experimental', 'result', 'significant', 'parallel', 'processing', 'speed', 'attributable', 'key', 'feature', 'method', 'large', 'number', 'lock', 'preemptible', 'search', 'job', 'random', 'priority', 'assignment', 'source', 'search', 'region', 'aggressive', 'deadlock', 'detection', 'resolution', 'algorithm', 'paper', 'describe', 'portable', 'generalized', 'thread', 'model', 'model', 'support', 'light', 'weight', 'job', 'abstraction', 'greatly', 'simplify', 'parallel', 'vision', 'programming'], tags=['4']),
#  TaggedDocument(words=['exist', 'algorithm', 'pronoun', 'resolution', 'typically', 'cast', 'problem', 'coreference', 'task', 'mean', 'simply', 'identify', 'antecedent', 'noun', 'phrase', 'pronoun', 'selection', 'antecedent', 'usually', 'base', 'calculation', 'salience', 'focus', 'simplified', 'approach', 'unable', 'account', 'pronoun', 'noun', 'phrase', 'antecedent', 'example', 'abstract', 'referent', 'event', 'proposition', 'speech', 'act', 'appear', 'linguistic', 'surface', 'form', 'sentential', 'complement', 'verbal', 'construction', 'entire', 'sentence', 'consequence', 'outcome', 'appear', 'surface', 'form', 'paper', 'contain', 'survey', 'current', 'method', 'pronoun', 'resolution', 'natural', 'language', 'understanding', 'propose', 'strategy', 'resolve', 'pronominal', 'reference', 'abstract', 'entity', 'incorporate', 'semantic', 'information', 'addition', 'salience', 'calculation', 'preliminary', 'experiment', 'describe', 'strategy', 'perform', 'baseline', 'collection', 'spoken', 'task', 'orient', 'dialog'], tags=['5']),
#  TaggedDocument(words=['appearance', 'base', 'object', 'recognition', 'system', 'rely', 'training', 'imagery', 'allow', 'recognition', 'object', 'require', 'geometric', 'model', 'little', 'explore', 'system', 'train', 'imagery', 'unlabeled', 'train', 'imagery', 'trivially', 'segmentable', 'paper', 'present', 'method', 'minimally', 'supervise', 'training', 'previously', 'develop', 'recognition', 'system', 'unlabeled', 'unsegmented', 'imagery', 'system', 'successfully', 'extend', 'object', 'representation', 'extract', 'black', 'background', 'image', 'contain', 'object', 'feature', 'extract', 'unlabeled', 'clutter', 'image', 'use', 'extended', 'representation', 'improve', 'recognition', 'performance', 'test', 'set'], tags=['6']),
#  TaggedDocument(words=['study', 'fall', 'computer', 'programming', 'csc', 'course', 'provide', 'detailed', 'analysis', 'relationship', 'variable', 'workshop', 'attendance', 'gender', 'ethnicity', 'prior', 'student', 'ability', 'student', 'performance', 'result', 'detail', 'subsequent', 'section', 'suggest', 'follow', 'workshop', 'attendance', 'significantly', 'positive', 'impact', 'student', 'performance', 'control', 'variation', 'gender', 'prior', 'student', 'ability', 'small', 'sample', 'size', 'female', 'minority', 'group', 'magnitude', 'role', 'gender', 'ethnicity', 'play', 'affect', 'student', 'performance', 'conclusively', 'determine', 'base', 'statistical', 'analysis', 'withdraw', 'female', 'student', 'perform', 'significantly', 'male', 'counterpart', 'attend', 'workshop', 'average', 'female', 'student', 'complete', 'course', 'perform', 'significantly', 'differently', 'male', 'counterpart', 'prior', 'student', 'ability', 'measure', 'sat', 'score', 'significant', 'affect', 'student', 'performance', 'control', 'prior', 'student', 'ability', 'alter', 'effect', 'workshop', 'attendance', 'performance', 'slightly', 'ols', 'regression', 'result', 'suggest', 'overestimation', 'logistic', 'regression', 'result', 'suggest', 'underestimation', 'effect', 'prior', 'add', 'sat', 'score'], tags=['7']),
#  TaggedDocument(words=['argue', 'transaction', 'synchronization', 'primitive', 'ordering', 'base', 'memory', 'consistency', 'model', 'define', 'transaction', 'term', 'lock', 'model', 'define', 'lock', 'condition', 'atomic', 'volatile', 'variable', 'term', 'transaction', 'traditional', 'critical', 'section', 'particular', 'region', 'code', 'bracket', 'transaction', 'certain', 'datum', 'privatize', 'memory', 'model', 'originally', 'publish', 'base', 'database', 'notion', 'strict', 'serializability', 'ss', 'explicit', 'analogy', 'adve', 'hill', 'demonstrate', 'ss', 'provide', 'appearance', 'transactional', 'sequential', 'consistency', 'tsc', 'program', 'transactional', 'datum', 'race', 'free', 'tdrf', 'argue', 'relaxation', 'total', 'order', 'transaction', 'selective', 'relaxation', 'relationship', 'program', 'order', 'transaction', 'order', 'selective', 'strict', 'serializability', 'sss', 'allow', 'implementation', 'transaction', 'base', 'lock', 'efficient', 'conventional', 'lock', 'condition', 'synchronoication', 'form', 'transaction', 'retry', 'primitive', 'accommodate', 'model', 'explicit', 'mention', 'speculation', 'opacity', 'abort', 'transaction', 'finally', 'compare', 'ss', 'sss', 'notion', 'strong', 'isolation', 'si', 'argue', 'si', 'sufficient', 'tsc', 'necessary', 'program', 'tdrf'], tags=['8']),
#  TaggedDocument(words=['recently', 'et', 'al', 'show', 'class', 'include', 'pspace', 'np', 'hold', 'nontrivial', 'complete', 'language', 'autoreducible', 'immediately', 'raise', 'question', 'complete', 'language', 'ture', 'self', 'reducible', 'class', 'paper', 'consider', 'simple', 'version', 'question', 'pspace', 'complete', 'np', 'complete', 'language', 'length', 'decrease', 'self', 'reducible', 'pspace', 'complete', 'language', 'length', 'decrease', 'self', 'reducible', 'pspace', 'p', 'np', 'complete', 'language', 'length', 'decrease', 'self', 'reducible', 'np', 'type', 'result', 'hold', 'natural', 'complexity', 'class', 'particular', 'nl', 'complete', 'set', 'logspace', 'length', 'decrease', 'self', 'reducible', 'unconditionally', 'pspace', 'complete', 'language', 'logspace', 'length', 'decrease', 'self', 'reducible', 'unconditionally', 'exp', 'complete', 'language', 'polynomial', 'time', 'length', 'decrease', 'self', 'reducible'], tags=['9']),
#  TaggedDocument(words=['recent', 'system', 'semantic', 'role', 'labeling', 'dependent', 'specific', 'predicate', 'corpora', 'train', 'label', 'new', 'datum', 'expensive', 'study', 'feature', 'classifier', 'best', 'able', 'generalize', 'unseen', 'predicate', 'new', 'semantic', 'frame', 'find', 'automatically', 'derive', 'cluster', 'information', 'especially', 'helpful', 'setting', 'relatively', 'simple', 'posteriori', 'classifier', 'outperform', 'maximum', 'entropy'], tags=['10']),
#  TaggedDocument(words=['datum', 'layout', 'program', 'critical', 'performance', 'determine', 'spatial', 'locality', 'data', 'access', 'quantitative', 'notion', 'spatial', 'locality', 'base', 'overall', 'miss', 'rate', 'leave', 'question', 'fully', 'answer', 'locality', 'give', 'data', 'layout', 'improve', 'data', 'layout', 'improve', 'miss', 'rate', 'lower', 'overall', 'spatial', 'locality', 'decompose', 'small', 'component', 'paper', 'describe', 'new', 'definition', 'spatial', 'locality', 'address', 'question', 'model', 'base', 'line', 'profiling', 'sequential', 'execution', 'analyze', 'spatial', 'locality', 'benchmark'], tags=['11']),
#  TaggedDocument(words=['domain', 'task', 'decompose', 'set', 'independent', 'sub', 'goal', 'task', 'complex', 'learn', 'standard', 'technique', 'reinforcement', 'learning', 'complexity', 'cause', 'learn', 'system', 'have', 'track', 'status', 'sub', 'goal', 'concurrently', 'solution', 'sub', 'goal', 'know', 'sub', 'goal', 'give', 'state', 'know', 'solution', 'relearn', 'status', 'sub', 'goal', 'change', 'dissertation', 'present', 'modular', 'approach', 'reinforcement', 'learning', 'take', 'advantage', 'task', 'decomposition', 'avoid', 'unnecessary', 'relearning', 'modular', 'approach', 'module', 'create', 'learn', 'sub', 'goal', 'module', 'receive', 'input', 'relevant', 'associated', 'sub', 'goal', 'learn', 'affect', 'state', 'sub', 'goal', 'furthermore', 'module', 'search', 'small', 'space', 'define', 'input', 'consider', 'greatly', 'reduce', 'learn', 'time', 'module', 'learn', 'achieve', 'separate', 'sub', 'goal', 'give', 'time', 'recommend', 'action', 'different', 'recommend', 'module', 'select', 'action', 'good', 'satisfie', 'module', 'possible', 'simple', 'arbitration', 'strategy', 'strategy', 'explore', 'dissertation', 'call', 'great', 'simply', 'combine', 'action', 'utility', 'module', 'select', 'large', 'combine', 'utility', 'modular', 'approach', 'limit', 'separate', 'information', 'give', 'module', 'solution', 'learn', 'necessarily', 'differ', 'learn', 'standard', 'non', 'modular', 'approach', 'experiment', 'simple', 'driving', 'world', 'indicate', 'sub', 'optimal', 'solution', 'learn', 'modular', 'system', 'make', 'minor', 'error', 'compare', 'learn', 'standard', 'approach', 'complex', 'task', 'learn', 'quickly', 'small', 'amount', 'computational', 'resource', 'small', 'sacrifice', 'solution', 'quality', 'modular', 'approach'], tags=['12']),
#  TaggedDocument(words=['robot', 'skill', 'learn', 'robot', 'obtain', 'datum', 'training', 'execute', 'expensive', 'practice', 'trial', 'record', 'result', 'thesis', 'high', 'cost', 'acquire', 'training', 'datum', 'limit', 'factor', 'performance', 'skill', 'learner', 'data', 'obtain', 'practice', 'trial', 'important', 'system', 'intelligent', 'choice', 'action', 'attempt', 'practice', 'dissertation', 'present', 'algorithm', 'intelligent', 'experimentation', 'skill', 'learning', 'open', 'loop', 'skill', 'execution', 'goal', 'present', 'controller', 'choose', 'control', 'signal', 'duration', 'task', 'learning', 'high', 'dimensional', 'search', 'problem', 'system', 'associate', 'sequence', 'action', 'commandable', 'goal', 'propose', 'algorithm', 'select', 'practice', 'action', 'likely', 'improve', 'performance', 'make', 'use', 'information', 'gain', 'previous', 'trial', 'problem', 'learn', 'throw', 'ball', 'robot', 'flexible', 'link', 'algorithm', 'take', 'trial', 'find', 'whip', 'motion', 'long', 'throw', 'closed', 'loop', 'learner', 'improve', 'performance', 'gradient', 'descent', 'cost', 'function', 'main', 'drawback', 'method', 'convergence', 'non', 'optimal', 'local', 'minima', 'introduce', 'concept', 'cooperation', 'means', 'escape', 'local', 'minimum', 'assume', 'existence', 'coach', 'improve', 'aspect', 'controller', 'performance', 'switch', 'training', 'coach', 'help', 'controller', 'avoid', 'locally', 'minimal', 'solution', 'task', 'curve', 'trace', 'invert', 'pendulum', 'cooperative', 'algorithm', 'learn', 'track', 'faster', 'traditional', 'method', 'integrate', 'system', 'scarce', 'sensor', 'resource', 'preferable', 'perform', 'task', 'sense', 'observe', 'closed', 'loop', 'learning', 'function', 'efficient', 'search', 'technique', 'open', 'loop', 'control', 'system', 'start', 'closed', 'loop', 'learning', 'improve', 'ability', 'control', 'plant', 'replace', 'sensor', 'information', 'estimate', 'result', 'controller', 'track', 'long', 'segment', 'reference', 'curve', 'open', 'loop'], tags=['13']),
#  TaggedDocument(words=['describe', 'method', 'object', 'recognition', 'base', 'stage', 'use', 'general', 'purpose', 'associative', 'memory', 'principal', 'view', 'representation', 'basic', 'idea', 'use', 'semi', 'invariant', 'object', 'call', 'key', 'key', 'robustly', 'extractable', 'feature', 'sufficient', 'information', 'content', 'specify', 'configuration', 'associated', 'object', 'location', 'scale', 'orientation', 'plus', 'sufficient', 'additional', 'parameter', 'provide', 'efficient', 'indexing', 'meaningful', 'verification', 'recognition', 'system', 'utilize', 'associative', 'memory', 'organize', 'access', 'key', 'feature', 'evoke', 'associate', 'hypothesis', 'identity', 'configuration', 'object', 'produce', 'hypothesis', 'feed', 'second', 'stage', 'associative', 'memory', 'maintain', 'probabilistic', 'estimate', 'likelihood', 'hypothesis', 'base', 'statistic', 'occurrence', 'key', 'primary', 'database', 'base', 'merged', 'percept', 'local', 'feature', 'global', 'property', 'method', 'robust', 'occlusion', 'background', 'clutter', 'require', 'prior', 'segmentation', 'entry', 'object', 'memory', 'active', 'automatic', 'procedure', 'implement', 'version', 'system', 'allow', 'arbitrary', 'definition', 'key', 'feature', 'experiment', 'key', 'base', 'perceptual', 'group', 'line', 'segment', 'report', 'good', 'result', 'obtain', 'database', 'derive', 'approximately', 'image', 'represent', 'different', 'view', 'polyhedral', 'object'], tags=['14']),
#  TaggedDocument(words=['argue', 'engineering', 'choice', 'design', 'computational', 'machinery', 'fundamental', 'difficulty', 'achieve', 'translation', 'invariance', 'vision', 'system', 'widely', 'misunderstood', 'image', 'processing', 'community', 'far', 'relatively', 'trivial', 'problem', 'translation', 'invariance', 'represent', 'complex', 'abstraction', 'equivalent', 'difficulty', 'consider', 'complete', 'important', 'class', 'structural', 'distortion', 'problem', 'argue', 'class', 'abstraction', 'important', 'sense', 'efficiently', 'learnable', 'fact', 'significant', 'implication', 'ability', 'plastic', 'system', 'brain', 'able', 'acquire', 'learn', 'member', 'class'], tags=['15']),
#  TaggedDocument(words=['give', 'p', 'order', 'universe', 'string', 'transitive', 'reflexive', 'antisymmetric', 'relation', 'x', 'y', 'element', 'polynomially', 'bound', 'interval', 'size', 'function', 'return', 'string', 'x', 'universe', 'number', 'string', 'interval', 'string', 'respect', 'function', 'polynomial', 'time', 'computable', 'length', 'choose', 'set', 'interval', 'size', 'function', 'base', 'feasibility', 'requirement', 'underlie', 'p', 'order', 'obtain', 'new', 'characterization', 'complexity', 'class', 'prove', 'set', 'interval', 'size', 'function', 'underlie', 'p', 'order', 'polynomial', 'time', 'decidable', 'exactly', 'interval', 'size', 'function', 'order', 'polynomial', 'time', 'adjacency', 'check', 'closely', 'relate', 'class', 'exactly', 'class', 'nonnegative', 'function', 'interval', 'size', 'function', 'minus', 'polynomial', 'time', 'computable', 'function', 'study', 'important', 'function', 'relation', 'interval', 'size', 'function', 'function', 'div', 'map', 'natural', 'number', 'n', 'number', 'nontrivial', 'divisor', 'div', 'interval', 'size', 'function', 'polynomial', 'time', 'decidable', 'partial', 'p', 'order', 'polynomial', 'time', 'adjacency', 'check', 'function', 'monsat', 'map', 'monotone', 'boolean', 'formula', 'f', 'number', 'satisfy', 'assignment', 'monsat', 'interval', 'size', 'function', 'polynomial', 'time', 'decidable', 'total', 'p', 'order', 'polynomial', 'time', 'adjacency', 'check', 'finally', 'explore', 'related', 'notion', 'cluster', 'computation'], tags=['16']),
#  TaggedDocument(words=['control', 'bribery', 'setting', 'external', 'agent', 'seek', 'influence', 'outcome', 'election', 'constructive', 'control', 'election', 'refer', 'attempt', 'agent', 'action', 'addition', 'deletion', 'partition', 'candidate', 'voter', 'ensure', 'give', 'candidate', 'win', 'destructive', 'control', 'refer', 'attempt', 'agent', 'action', 'preclude', 'give', 'candidate', 'victory', 'election', 'system', 'agent', 'affect', 'result', 'determine', 'polynomial', 'time', 'input', 'agent', 'succeed', 'say', 'vulnerable', 'give', 'type', 'control', 'election', 'system', 'agent', 'affect', 'result', 'np', 'hard', 'recognize', 'input', 'agent', 'succeed', 'say', 'resistant', 'give', 'type', 'control', 'aside', 'election', 'system', 'np', 'hard', 'winner', 'problem', 'system', 'previously', 'know', 'resistant', 'standard', 'control', 'type', 'highly', 'artificial', 'election', 'system', 'create', 'hybridization', 'paper', 'study', 'parameterize', 'version', 'copeland', 'voting', 'denote', 'parameter', 'rational', 'number', 'specify', 'tie', 'value', 'pairwise', 'comparison', 'candidate', 'previously', 'study', 'constructive', 'destructive', 'control', 'scenario', 'determine', 'resistance', 'vulnerability', 'hold', 'rational', 'particular', 'prove', 'system', 'commonly', 'refer', 'copeland', 'voting', 'provide', 'resistance', 'constructive', 'control', 'prove', 'rational', 'lt', 'lt', 'system', 'polynomial', 'time', 'winner', 'problem', 'copeland', 'voting', 'natural', 'election', 'system', 'prove', 'resistance', 'constructive', 'control', 'addition', 'prove', 'interestingly', 'election', 'system', 'develop', 'thirteenth', 'century', 'mystic', 'ramon', 'llull', 'resistant', 'standard', 'type', 'constructive', 'control', 'variant', 'addition', 'candidate', 'rational', 'voting', 'fully', 'resistant', 'bribery', 'attack', 'establish', 'fix', 'parameter', 'tractability', 'bound', 'case', 'control', 'study', 'election', 'flexible', 'model', 'microbribery', 'extended', 'control', 'integrate', 'potential', 'irrationality', 'voter', 'preference', 'result', 'prove', 'result', 'unique', 'winner', 'model', 'nonunique', 'winner', 'model', 'vulnerability', 'result', 'microbribery', 'prove', 'novel', 'technique', 'involve', 'min', 'cost', 'network', 'flow'], tags=['17']),
#  TaggedDocument(words=['proceeding', 'workshop', 'hold', 'conjunction', 'international', 'international', 'conference', 'machine', 'learning', 'july', 'tahoe', 'city'], tags=['18']),
#  TaggedDocument(words=['filesystem', 'sole', 'purpose', 'store', 'datum', 'easily', 'access', 'later', 'time', 'entail', 'recover', 'properly', 'system', 'crash', 'difficulty', 'modern', 'filesystem', 'face', 'advent', 'write', 'cache', 'disk', 'disk', 'report', 'write', 'operation', 'complete', 'data', 'actually', 'secure', 'magnetic', 'platter', 'programmer', 'respond', 'outright', 'lie', 'hardware', 'problem', 'go', 'journale', 'filesystem', 'depend', 'order', 'write', 'operation', 'send', 'disk', 'real', 'datum', 'write', 'journal', 'point', 'have', 'journal', 'actually', 'give', 'false', 'sense', 'security', 'crash', 'disk', 'checker', 'replay', 'journal', 'bother', 'examine', 'real', 'datum', 'disk', 'consistency', 'solution', 'problem', 'call', 'tagged', 'command', 'queuing', 'tcq', 'specification', 'optional', 'filesystem', 'particular', 'paper', 'use', 'tcq', 'exclusively', 'fallback', 'present', 'fallback', 'solution', 'depend', 'required', 'feature', 'specification', 'force', 'unit', 'access', 'fua', 'result', 'show', 'write', 'intensive', 'workload', 'display', 'significant', 'slowdown', 'fua', 'base', 'solution', 'performance', 'impact', 'incur', 'method', 'synchronize', 'cache', 'journal', 'write'], tags=['19']),
#  TaggedDocument(words=['human', 'being', 'innate', 'ability', 'educe', 'meaning', 'mass', 'datum', 'discover', 'exploit', 'regularity', 'pattern', 'world', 'jump', 'obvious', 'paper', 'present', 'system', 'discover', 'law', 'richly', 'structure', 'world', 'inspire', 'form', 'human', 'reasoning', 'previous', 'work', 'rule', 'discovery', 'work', 'impoverished', 'domain', 'describable', 'list', 'object', 'value', 'pair', 'representation', 'admit', 'relatively', 'efficient', 'algorithm', 'poor', 'describe', 'interesting', 'feature', 'real', 'world', 'logical', 'system', 'survey', 'recent', 'work', 'field', 'relational', 'data', 'mining', 'seek', 'extend', 'algorithm', 'rich', 'domain', 'previous', 'approach', 'problem', 'work', 'search', 'space', 'syntactically', 'correct', 'rule', 'statement', 'satisfy', 'certain', 'criterion', 'search', 'guide', 'linguistic', 'declarative', 'bias', 'hypothesize', 'possible', 'rule', 'order', 'test', 'argue', 'space', 'possible', 'rule', 'large', 'search', 'effectively', 'manner', 'propose', 'alternative', 'data', 'drive', 'search', 'paradigm', 'search', 'guide', 'relationship', 'form', 'hypothesize', 'rule', 'correlation', 'datum', 'represent', 'argue', 'pattern', 'drive', 'search', 'enable', 'detection', 'rich', 'powerful', 'hypothesis', 'include', 'involve', 'equality', 'nest', 'quantification', 'present', 'prototype', 'system', 'incorporate', 'idea', 'result', 'obtain', 'apply', 'problem', 'detect', 'invariant', 'arbitrary', 'planning', 'world', 'finally', 'discuss', 'way', 'extend', 'approach', 'realistic', 'domain', 'extend', 'discovery', 'process', 'enable', 'create', 'new', 'concept', 'necessary', 'better', 'describe', 'datum'], tags=['20']),
#  TaggedDocument(words=['considerable', 'recent', 'interest', 'support', 'transactional', 'memory', 'tm', 'hardware', 'software', 'present', 'intermediate', 'approach', 'hardware', 'accelerate', 'tm', 'implementation', 'control', 'fundamentally', 'software', 'hardware', 'support', 'reduce', 'overhead', 'common', 'tm', 'task', 'conflict', 'detection', 'datum', 'isolation', 'bound', 'transaction', 'software', 'control', 'allow', 'policy', 'flexibility', 'conflict', 'detection', 'contention', 'management', 'datum', 'granularity', 'addition', 'enable', 'transaction', 'unbounde', 'space', 'time', 'hardware', 'consist', 'alert', 'update', 'mechanism', 'fast', 'event', 'base', 'communication', 'software', 'control', 'conflict', 'detection', 'support', 'programmable', 'datum', 'isolation', 'allow', 'multiple', 'concurrent', 'transactional', 'reader', 'writer', 'software', 'behest', 'fast', 'datum', 'commit', 'abort', 'support', 'cycle', 'completely', 'local', 'operation', 'result', 'common', 'case', 'bound', 'transaction', 'propose', 'hardware', 'mechanism', 'eliminate', 'datum', 'copying', 'dramatically', 'reduce', 'overhead', 'bookkeeping', 'validation', 'result', 'factor', 'improvement', 'performance', 'average', 'rtm', 'show', 'good', 'scalability', 'number', 'thread', 'increase', 'graceful', 'degradation', 'performance', 'transaction', 'overflow', 'available', 'hardware', 'support', 'detect', 'conflict', 'eagerly', 'access', 'lazily', 'commit', 'time', 'enable', 'ability', 'handle', 'multiple', 'concurrent', 'transactional', 'writer', 'reader', 'result', 'difference', 'performance', 'direction', 'depend', 'application', 'access', 'pattern', 'order', 'magnitude', 'thread', 'workload', 'demonstrate', 'need', 'policy', 'flexibility'], tags=['21']),
#  TaggedDocument(words=['central', 'difficulty', 'automatic', 'speech', 'recognition', 'temporally', 'inaccurate', 'nature', 'speech', 'signal', 'despite', 'speech', 'traditionally', 'model', 'purely', 'sequential', 'albeit', 'probabilistic', 'process', 'usefulness', 'accurate', 'sequence', 'information', 'evaluate', 'paper', 'acoustic', 'lexical', 'level', 'task', 'speech', 'recognition', 'acoustic', 'level', 'speech', 'segment', 'quantize', 'discrete', 'vector', 'convert', 'set', 'representation', 'oppose', 'accurate', 'sequence', 'recognition', 'quantize', 'vector', 'set', 'dramatically', 'improve', 'performance', 'contrast', 'corresponding', 'vector', 'sequence', 'representation', 'lexical', 'level', 'study', 'suggest', 'accurate', 'sequence', 'information', 'crucial', 'fact', 'locally', 'discard', 'phoneme', 'sequence', 'information', 'useful', 'cope', 'error', 'insertion', 'substitution', 'base', 'idea', 'phone', 'set', 'indexing', 'lexical', 'access', 'algorithm', 'develop', 'work', 'question', 'traditional', 'approach', 'model', 'speech', 'purely', 'sequential', 'process', 'suggest', 'discard', 'local', 'sequential', 'information', 'good', 'idea', 'alternative', 'purely', 'sequential', 'representation', 'set', 'representation', 'viable', 'option'], tags=['22']),
#  TaggedDocument(words=['paper', 'describe', 'prosodic', 'information', 'correlate', 'topic', 'structure', 'cooperative', 'dialogue', 'investigate', 'correlation', 'systematically', 'introduce', 'notion', 'utterance', 'unit', 'uu', 'basic', 'unit', 'conversation', 'define', 'utterance', 'unit', 'employ', 'principle', 'grammatical', 'principle', 'syntactic', 'criterion', 'uu', 'boundary', 'set', 'period', 'place', 'pragmatic', 'principle', 'say', 'uu', 'correspond', 'basic', 'speech', 'act', 'word', 'neighboring', 'phrase', 'correspond', 'different', 'speech', 'act', 'instance', 'acknowledgment', 'request', 'take', 'different', 'uu', 'conversational', 'principle', 'address', 'turn', 'taking', 'aspect', 'conversation', 'uu', 'boundary', 'place', 'speaker', 'change', 'finally', 'prosodic', 'principle', 'say', 'medium', 'length', 'long', 'pause', 'msec', 'insert', 'phrase', 'take', 'different', 'uu', 'apply', 'principle', 'speech', 'database', 'contain', 'half', 'hour', 'collect', 'dialogue', 'split', 'dialogue', 'sequence', 'uu', 'classify', 'inter', 'uu', 'boundary', 'base', 'relationship', 'neighbor', 'uu', 'semantic', 'category', 'topic', 'shift', 'topic', 'continuation', 'elaboration', 'clarification', 'speech', 'act', 'continuation', 'prosodic', 'parameter', 'measure', 'boundary', 'onset', 'fundamental', 'frequency', 'final', 'maximal', 'peak', 'declination', 'ratio', 'ratio', 'current', 'uuus', 'maximal', 'peak', 'precede', 'uu', 'study', 'show', 'prosodic', 'parameter', 'vary', 'depend', 'topic', 'structure', 'result', 'summarize', 'follow', 'onset', 'value', 'tend', 'high', 'topic', 'change', 'uu', 'boundary', 'final', 'value', 'indicate', 'finality', 'high', 'average', 'speech', 'act', 'continuation', 'boundary', 'boundary', 'maximal', 'peak', 'declination', 'ratio', 'reflect', 'degree', 'subordination', 'precede', 'uu', 'ratio', 'low', 'elaboration', 'boundary', 'high', 'topic', 'shift', 'boundary', 'finally', 'discuss', 'discourse', 'structure', 'identification', 'prosodic', 'parameter'], tags=['23']),
#  TaggedDocument(words=['self', 'awareness', 'aspect', 'consciousness', 'highly', 'develop', 'human', 'comparison', 'animal', 'human', 'unaware', 'personal', 'characteristic', 'know', 'know', 'want', 'want', 'experience', 'experience', 'etc', 'surely', 'difficult', 'communicate', 'naturally', 'believe', 'consciousness', 'play', 'crucial', 'role', 'build', 'artificial', 'dialog', 'agent', 'human', 'level', 'ability', 'provide', 'overview', 'consciousness', 'view', 'philosophy', 'biology', 'artificial', 'intelligence', 'present', 'relevant', 'work', 'agent', 'ability', 'relate', 'consciousness', 'present', 'initial', 'attempt', 'extend', 'architecture', 'simple', 'epilog', 'base', 'agent', 'originally', 'build', 'kaplan', 'direction', 'goal', 'human', 'like', 'conscious', 'dialog', 'agent'], tags=['24']),
#  TaggedDocument(words=['rabi', 'sherman', 'prove', 'hardness', 'factoring', 'sufficient', 'condition', 'exist', 'way', 'function', 'p', 'time', 'computable', 'honest', 'p', 'time', 'noninvertible', 'function', 'paper', 'bad', 'case', 'model', 'average', 'case', 'model', 'total', 'commutative', 'associative', 'strongly', 'noninvertible', 'paper', 'improve', 'sufficient', 'condition', 'p', 'equal', 'np', 'generally', 'paper', 'completely', 'characterize', 'type', 'way', 'function', 'stand', 'fall', 'plain', 'way', 'function', 'equivalently', 'stand', 'fall', 'p', 'equal', 'np', 'look', 'attribute', 'rabi', 'sherman', 'seminal', 'work', 'algebraic', 'property', 'way', 'function', 'subsequent', 'paper', 'strongness', 'noninvertibility', 'totality', 'commutativity', 'associativity', 'attribute', 'allow', 'require', 'hold', 'require', 'fail', 'care', 'categorization', 'potential', 'type', 'way', 'function', 'prove', 'feature', 'laden', 'type', 'stand', 'fall', 'existence', 'plain', 'way', 'function'], tags=['25']),
#  TaggedDocument(words=['trains', 'project', 'effort', 'build', 'conversationally', 'proficient', 'planning', 'assistant', 'key', 'project', 'construction', 'trains', 'system', 'provide', 'research', 'platform', 'wide', 'range', 'issue', 'natural', 'language', 'understanding', 'mixed', 'initiative', 'planning', 'system', 'represent', 'reason', 'time', 'action', 'event', 'year', 'pass', 'beginning', 'project', 'year', 'produce', 'demonstration', 'system', 'focus', 'dialog', 'illustrate', 'particular', 'aspect', 'research', 'commitment', 'build', 'complete', 'integrate', 'system', 'significant', 'overhead', 'research', 'feel', 'essential', 'guarantee', 'result', 'constitute', 'real', 'progress', 'field', 'paper', 'describe', 'goal', 'project', 'experience', 'effort', 'far', 'paper', 'appear', 'journal', 'experimental', 'theoretical', 'ai'], tags=['26']),
#  TaggedDocument(words=['problem', 'ambiguity', 'central', 'theory', 'language', 'interpretation', 'interest', 'language', 'processing', 'human', 'develop', 'usable', 'natural', 'language', 'processing', 'system', 'psycholinguistic', 'evidence', 'suggest', 'human', 'subject', 'able', 'choose', 'interpretation', 'necessary', 'compete', 'factor', 'involve', 'choice', 'theory', 'language', 'interpretation', 'deal', 'satisfactorily', 'combinatorial', 'explosion', 'paradox', 'fact', 'matter', 'ambiguous', 'natural', 'language', 'sentence', 'usually', 'interpret', 'significant', 'effort', 'main', 'idea', 'present', 'dissertation', 'scope', 'preference', 'observe', 'literature', 'obtain', 'independent', 'scope', 'disambiguation', 'module', 'result', 'independent', 'interpretation', 'process', 'definite', 'description', 'interpretation', 'interpretation', 'modal', 'interpretive', 'procedure', 'especially', 'concerned', 'scope', 'disambiguation', 'result', 'inference', 'relation', 'contextual', 'dependency', 'anaphoric', 'reference', 'presuppositionality', 'common', 'ground', 'scope', 'preference', 'observe', 'literature', 'reflect', 'relation', 'dependency', 'dissertation', 'include', 'formal', 'proposal', 'concern', 'representation', 'contextual', 'dependency', 'impact', 'semantic', 'sentence', 'constituent', 'theory', 'ambiguity', 'present', 'base', 'distinction', 'semantic', 'ambiguity', 'capture', 'implicitly', 'mean', 'underspecified', 'representation', 'perceive', 'ambiguity', 'result', 'process', 'discourse', 'interpretation', 'new', 'model', 'common', 'ground', 'introduce', 'characterize', 'situation', 'characterize', 'presence', 'semantic', 'ambiguity', 'situation', 'characterize', 'existence', 'perceive', 'ambiguity', 'reasoning', 'lead', 'establishment', 'scoping', 'preference', 'make', 'use', 'argue', 'information', 'pragmatic', 'nature', 'call', 'model', 'discourse', 'interpretation', 'common', 'ground', 'contain', 'information', 'case', 'spoken', 'language', 'conversation', 'common', 'ground', 'model', 'discourse', 'situation', 'conversational', 'participant'], tags=['27']),
#  TaggedDocument(words=['software', 'transactional', 'memory', 'stm', 'system', 'support', 'condition', 'synchronization', 'typically', 'retry', 'mechanism', 'retry', 'transaction', 'explicitly', 'self', 'abort', 'deschedule', 'discover', 'precondition', 'operation', 'hold', 'underlie', 'implementation', 'track', 'set', 'location', 'read', 'retrying', 'transaction', 'refrain', 'schedule', 'transaction', 'execution', 'location', 'set', 'modify', 'transaction', 'retry', 'elegant', 'simple', 'conventional', 'implementation', 'potential', 'drawback', 'limit', 'efficiency', 'generality', 'note', 'present', 'retry', 'mechanism', 'base', 'bloom', 'filter', 'entirely', 'orthogonal', 'tm', 'implementation', 'retry', 'compatible', 'hardware', 'software', 'hybrid', 'tm', 'implementation', 'impact', 'memory', 'management', 'cache', 'behavior', 'shared', 'location', 'serialize', 'writer', 'transaction', 'commit', 'point', 'retry', 'transaction', 'describe', 'mechanism', 'compare', 'optimized', 'version', 'conventional', 'implementation'], tags=['28']),
#  TaggedDocument(words=['scalp', 'eeg', 'recording', 'measure', 'microvolt', 'electrical', 'signal', 'easily', 'interfere', 'experiment', 'spehlmann', 'discusse', 'interference', 'introduce', 'light', 'recording', 'room', 'nearby', 'television', 'computer', 'monitor', 'spehlmann', 'consider', 'perform', 'eeg', 'ep', 'erp', 'experiment', 'virtual', 'reality', 'helmet', 'contain', 'eye', 'tracker', 'electrical', 'interference', 'real', 'possibility', 'test', 'effect', 'wear', 'virtual', 'reality', 'vr', 'helmet', 'contain', 'iscan', 'eye', 'tracker', 'ask', 'subject', 'continuous', 'performance', 'task', 'result', 'task', 'analyze', 'frequency', 'domain', 'compare', 'result', 'experiment', 'look', 'computer', 'screen', 'different', 'environment', 'result', 'indicate', 'environment', 'computer', 'vertical', 'refresh', 'nearby', 'row', 'computer', 'monitor', 'add', 'noise', 'signal', 'wear', 'vr', 'helmet', 'eye', 'tracker', 'environment', 'computer', 'noise', 'wear', 'vr', 'helmet', 'eye', 'tracker', 'significantly', 'different', 'noise', 'obtain', 'view', 'laptop', 'computer', 'screen', 'location'], tags=['29']),
#  TaggedDocument(words=['safety', 'speculative', 'parallelization', 'depend', 'monitor', 'program', 'access', 'share', 'datum', 'automatic', 'solution', 'use', 'program', 'instrumentation', 'costly', 'hardware', 'base', 'triggering', 'incur', 'false', 'sharing', 'addition', 'access', 'require', 'monitoring', 'worth', 'consider', 'manual', 'approach', 'programmer', 'insert', 'access', 'annotation', 'reduce', 'cost', 'increase', 'precision', 'program', 'monitoring', 'report', 'present', 'execution', 'model', 'interface', 'access', 'annotation', 'semantic', 'annotated', 'program', 'define', 'output', 'sequential', 'canonical', 'execution', 'report', 'describe', 'quadratic', 'time', 'checker', 'verify', 'safety', 'annotation', 'speculative', 'execution', 'produce', 'canonical', 'output', 'report', 'demonstrate', 'usability', 'annotation', 'interface', 'safely', 'parallelize', 'number', 'code', 'fragment', 'uncertain', 'parallelism'], tags=['30']),
#  TaggedDocument(words=['describe', 'design', 'implementation', 'video', 'base', 'augment', 'reality', 'system', 'capable', 'overlay', 'dimensional', 'graphical', 'object', 'live', 'video', 'dynamic', 'environment', 'key', 'feature', 'system', 'completely', 'uncalibrated', 'use', 'metric', 'information', 'calibration', 'parameter', 'camera', 'location', 'dimension', 'environment', 'object', 'requirement', 'ability', 'track', 'frame', 'feature', 'point', 'specify', 'user', 'system', 'initialization', 'time', 'world', 'coordinate', 'unknown', 'approach', 'base', 'follow', 'observation', 'give', 'set', 'non', 'coplanar', 'point', 'projection', 'point', 'set', 'compute', 'linear', 'combination', 'projection', 'point', 'exploit', 'observation', 'track', 'line', 'fiducial', 'point', 'frame', 'rate', 'represent', 'virtual', 'object', 'non', 'euclidean', 'affine', 'frame', 'reference', 'allow', 'projection', 'compute', 'linear', 'combination', 'projection', 'fiducial', 'point'], tags=['31']),
#  TaggedDocument(words=['paper', 'describe', 'formalism', 'statistical', 'event', 'logic', 'sel', 'add', 'statistical', 'reasoning', 'allen', 'planning', 'language', 'allen', 'et', 'al', 'reason', 'plan', 'interval', 'temporal', 'logic', 'support', 'reason', 'time', 'event', 'probability', 'infer', 'planner', 'experience', 'support', 'reason', 'incomplete', 'information', 'statistical', 'event', 'logic', 'represent', 'knowledge', 'allow', 'planner', 'reason', 'choice', 'base', 'incomplete', 'knowledge', 'future', 'likely', 'result', 'choice'], tags=['32']),
#  TaggedDocument(words=['david', 'lowe', 'influential', 'classic', 'algorithm', 'tracking', 'object', 'know', 'geometry', 'formulate', 'certain', 'simplify', 'assumption', 'version', 'implement', 'ishii', 'et', 'al', 'make', 'different', 'simplifying', 'assumption', 'formulate', 'projective', 'solution', 'apply', 'algorithm', 'newton', 'method', 'report', 'result', 'extensive', 'testing', 'algorithm', 'compute', 'image', 'space', 'pose', 'space', 'error', 'metric', 'quantify', 'effect', 'object', 'pose', 'error', 'initial', 'solution', 'image', 'noise', 'level', 'consider', 'scenaria', 'relatively', 'unconstrained', 'condition', 'mirror', 'real', 'world', 'real', 'time', 'constraint', 'conclusion', 'projective', 'formulation', 'make', 'algorithm', 'order', 'magnitude', 'accurate', 'give', 'super', 'exponential', 'convergence', 'property', 'arguably', 'well', 'computation', 'time', 'property'], tags=['33']),
#  TaggedDocument(words=['uncertain', 'reasoning', 'need', 'combine', 'conflict', 'piece', 'evidence', 'need', 'evidence', 'combination', 'arise', 'kyburg', 'evidential', 'probability', 'system', 'investigate', 'method', 'deal'], tags=['34']),
#  TaggedDocument(words=['study', 'complexity', 'follow', 'problem', 'give', 'weighted', 'voting', 'game', 'g', 'g', 'contain', 'player', 'p', 'game', 'p', 'power', 'index', 'value', 'high', 'study', 'problem', 'respect', 'shapley', 'shubik', 'power', 'index', 'banzhaf', 'power', 'index', 'main', 'result', 'power', 'indice', 'problem', 'complete', 'probabilistic', 'polynomial', 'time', 'apply', 'result', 'partially', 'resolve', 'recently', 'propose', 'problem', 'complexity', 'weighted', 'voting', 'game', 'study', 'complexity', 'raw', 'shapley', 'shubik', 'power', 'index', 'deng', 'papadimitriou', 'show', 'raw', 'shapley', 'shubik', 'power', 'index', 'p', 'metric', 'complete', 'strengthen', 'show', 'raw', 'shapley', 'shubik', 'power', 'index', 'complete', 'strengthening', 'possibly', 'improve', 'parsimonious', 'completeness', 'observe', 'contrast', 'raw', 'banzhaf', 'power', 'index', 'raw', 'shapley', 'shubik', 'power', 'index', 'p', 'parsimonious', 'complete'], tags=['35']),
#  TaggedDocument(words=['scene', 'classification', 'automatic', 'categorization', 'image', 'semantic', 'class', 'beach', 'field', 'party', 'useful', 'application', 'content', 'base', 'image', 'organization', 'context', 'sensitive', 'digital', 'enhancement', 'current', 'scene', 'classification', 'system', 'use', 'low', 'level', 'feature', 'pattern', 'recognition', 'technique', 'achieve', 'success', 'limited', 'domain', 'contemporary', 'classifier', 'include', 'develop', 'rochester', 'incorporate', 'semantic', 'material', 'object', 'detector', 'classification', 'performance', 'improve', 'gap', 'feature', 'image', 'semantic', 'narrow', 'propose', 'spatial', 'relationship', 'object', 'material', 'help', 'distinguish', 'certain', 'type', 'scene', 'mitigate', 'effect', 'detector', 'failure', 'past', 'work', 'spatial', 'modeling', 'rule', 'base', 'model', 'propose', 'probabilistic', 'framework', 'handle', 'loose', 'spatial', 'relationship', 'exist', 'scene', 'type', 'end', 'develop', 'masses', 'experimental', 'testbed', 'generate', 'virtual', 'scene', 'masse', 'experiment', 'different', 'spatial', 'model', 'different', 'detector', 'characteristic', 'different', 'learning', 'parameter', 'tree', 'structure', 'bayesian', 'network', 'inference', 'series', 'simulated', 'natural', 'scene', 'show', 'presence', 'key', 'spatial', 'relationship', 'need', 'disambiguate', 'type', 'scene', 'achieve', 'gain', 'case', 'simple', 'bayes', 'net', 'expressive', 'model', 'faulty', 'detection', 'level', 'individual', 'region', 'future', 'work', 'propose', 'evaluate', 'dag', 'bayesian', 'network', 'markov', 'random', 'fields', 'potential', 'probabilistic', 'framework', 'plan', 'extend', 'choose', 'framework', 'problem', 'finally', 'compare', 'result', 'real', 'simulated', 'set', 'image', 'obtain', 'system', 'spatial', 'feature', 'represent', 'implicitly'], tags=['36']),
#  TaggedDocument(words=['work', 'devote', 'past', 'year', 'complexity', 'protect', 'election', 'manipulation', 'control', 'result', 'obtain', 'show', 'np', 'hardness', 'shield', 'recently', 'focus', 'bad', 'case', 'hardness', 'protection', 'bypass', 'frequently', 'correct', 'heuristic', 'approximation', 'paper', 'take', 'different', 'approach', 'argue', 'electorate', 'follow', 'canonical', 'political', 'science', 'model', 'societal', 'preference', 'complexity', 'shield', 'exist', 'place', 'particular', 'electorate', 'have', 'single', 'peaked', 'preference', 'exist', 'np', 'hardness', 'result', 'manipulation', 'control', 'evaporate'], tags=['37']),
#  TaggedDocument(words=['report', 'discuss', 'creation', 'initial', 'annotation', 'monroe', 'corpus', 'collection', 'video', 'audio', 'datum', 'human', 'human', 'mixed', 'initiative', 'task', 'orient', 'dialog', 'disaster', 'handle', 'task', 'describe', 'dialog', 'collect', 'task', 'datum', 'transcribe', 'align'], tags=['38']),
#  TaggedDocument(words=['paper', 'present', 'computational', 'model', 'conversational', 'participant', 'collaborate', 'order', 'refer', 'action', 'successful', 'model', 'base', 'view', 'language', 'goal', 'direct', 'behavior', 'propose', 'content', 'refer', 'expression', 'account', 'planning', 'paradigm', 'approach', 'allow', 'process', 'build', 'refer', 'expression', 'identify', 'referent', 'capture', 'plan', 'construction', 'plan', 'inference', 'allow', 'account', 'participant', 'clarify', 'refer', 'expression', 'meta', 'action', 'reason', 'manipulate', 'plan', 'derivation', 'correspond', 'refer', 'expression', 'account', 'clarification', 'goal', 'arise', 'infer', 'clarification', 'plan', 'affect', 'agent', 'propose', 'agent', 'certain', 'state', 'mind', 'state', 'include', 'intention', 'achieve', 'goal', 'refer', 'plan', 'agent', 'currently', 'consider', 'mental', 'state', 'sanction', 'adoption', 'goal', 'acceptance', 'infer', 'plan', 'act', 'link', 'understanding', 'generation'], tags=['39']),
#  TaggedDocument(words=['research', 'recent', 'decade', 'aim', 'discover', 'underlying', 'principle', 'drive', 'brain', 'cortex', 'appear', 'basically', 'uniform', 'underlying', 'principle', 'ubiquitous', 'principle', 'propose', 'explain', 'brain', 'largely', 'specialized', 'principle', 'explain', 'particular', 'aspect', 'brain', 'principle', 'efficient', 'coding', 'predictive', 'coding', 'temporal', 'invariance', 'propose', 'explain', 'sensory', 'coding', 'succeed', 'measure', 'reproduce', 'receptive', 'field', 'property', 'neuron', 'visual', 'cortex', 'bayesian', 'surprise', 'offer', 'explanation', 'attention', 'enjoy', 'success', 'model', 'human', 'saccade', 'reinforcement', 'learning', 'intelligent', 'adaptive', 'curiosity', 'aim', 'explain', 'action', 'choose', 'dissertation', 'propose', 'novel', 'principle', 'predictive', 'action', 'information', 'theoretic', 'principle', 'unify', 'proposal', 'relationship', 'proposal', 'algorithm', 'approximate', 'predictive', 'action', 'specific', 'environment', 'hope', 'principle', 'allow', 'great', 'understanding', 'brain', 'serve', 'principle', 'basis', 'design', 'future', 'algorithm', 'solve', 'broad', 'range', 'problem', 'artificial', 'intelligence'], tags=['40']),
# ...
#  TaggedDocument(words=['describe', 'self', 'bootstrappe', 'adaptive', 'system', 'design', 'observation', 'outdoor', 'environment', 'determine', 'simple', 'environmental', 'condi', 'tion', 'specifically', 'day', 'night', 'condition', 'clear', 'cloudy', 'mixtur', 'system', 'adapt', 'operate', 'reliably', 'variety', 'location', 'envi', 'ronment', 'robust', 'change', 'season', 'weather', 'typical', 'human', 'non', 'human', 'disturbance', 'streetlights', 'thunderstorm', 'complex', 'problem', 'think', 'describe', 'practical', 'issue', 'technique', 'deal'], tags=['192']),
#  TaggedDocument(words=['modify', 'public', 'domain', 'quake', 'ii', 'game', 'support', 'research', 'teaching', 'research', 'multi', 'agent', 'control', 'support', 'human', 'computer', 'interface', 'teaching', 'application', 'far', 'undergraduate', 'artificial', 'intelligence', 'class', 'include', 'natural', 'language', 'understanding', 'machine', 'learning', 'computer', 'vision', 'production', 'system', 'control', 'motivation', 'report', 'mainly', 'document', 'system', 'development', 'interface', 'early', 'result', 'appear', 'promise', 'source', 'code', 'user', 'level', 'documentation', 'available', 'web', 'information', 'document', 'somewhat', 'motion', 'blur', 'snapshot', 'situation', 'september'], tags=['193']),
#  TaggedDocument(words=['document', 'describe', 'new', 'pattern', 'match', 'engine', 'discourse', 'reason', 'component', 'system', 'dominant', 'characteristic', 'simplicity', 'efficiency', 'economical', 'model', 'drive', 'search', 'engine'], tags=['194']),
#  TaggedDocument(words=['task', 'generic', 'object', 'recognition', 'involve', 'learn', 'identify', 'member', 'class', 'object', 'base', 'exemplar', 'class', 'generic', 'object', 'class', 'inherently', 'ill', 'define', 'object', 'group', 'class', 'base', 'vary', 'criterion', 'form', 'function', 'color', 'size', 'etc', 'work', 'develop', 'extension', 'study', 'view', 'base', 'rigid', 'object', 'recognizer', 'improve', 'performance', 'generic', 'object', 'class', 'group', 'shape', 'relate', 'class', 'object', 'loosely', 'structured', 'object', 'extension', 'use', 'cluster', 'underlying', 'local', 'context', 'feature', 'discover', 'feature', 'recur', 'object', 'class', 'modification', 'improve', 'performance', 'rigid', 'generic', 'loosely', 'structure', 'class', 'reliably', 'discover', 'recurrent', 'feature', 'analysis', 'show', 'performance', 'improvement', 'come', 'effect', 'cluster', 'algorithm', 'feature', 'tend', 'create', 'noise', 'system', 'marginalized', 'second', 'extension', 'take', 'principled', 'approach', 'estimate', 'quality', 'object', 'model', 'feature', 'base', 'robustness', 'commonness', 'noisy', 'feature', 'low', 'quality', 'score', 'contribute', 'noise', 'recognition', 'process', 'approach', 'improve', 'recognition', 'rigid', 'generic', 'loosely', 'structured', 'object', 'class', 'clustering', 'method', 'develop', 'active', 'recognition', 'system', 'achieve', 'well', 'recognition', 'utilize', 'additional', 'information', 'available', 'active', 'vision', 'setting', 'system', 'use', 'change', 'detection', 'perform', 'foreground', 'background', 'segmentation', 'scene', 'segmentation', 'information', 'command', 'pan', 'tilt', 'zoom', 'camera', 'acquire', 'high', 'resolution', 'image', 'target', 'region', 'scene', 'furthermore', 'segmentation', 'information', 'reduce', 'background', 'clutter', 'high', 'resolution', 'target', 'image', 'finally', 'describe', 'memory', 'assistant', 'application', 'build', 'active', 'recognition', 'system', 'application', 'design', 'assist', 'people', 'mild', 'moderate', 'memory', 'loss', 'track', 'important', 'object', 'home', 'environment', 'prototype', 'system', 'currently', 'deploy', 'center', 'future', 'health', 'university', 'rochester', 'medical', 'center'], tags=['195']),
#  TaggedDocument(words=['paper', 'orienting', 'establish', 'maintain', 'spatial', 'relation', 'motorize', 'pair', 'camera', 'eye', 'head', 'system', 'static', 'move', 'object', 'track', 'time', 'motivate', 'physiological', 'evidence', 'paper', 'propose', 'simple', 'set', 'vision', 'base', 'strategy', 'aim', 'perform', 'head', 'eye', 'body', 'movement', 'complex', 'environment', 'fixation', 'show', 'essential', 'feature', 'visual', 'servoing', 'decouple', 'control', 'head', 'rotational', 'degree', 'freedom', 'make', 'possible', 'metric', 'approach', 'orientation', 'problem', 'run', 'implementation', 'strategy', 'binocular', 'camera', 'system', 'mount', 'puma', 'demonstrate', 'effectiveness', 'approach'], tags=['196']),
#  TaggedDocument(words=['general', 'purpose', 'object', 'indexing', 'technique', 'describe', 'combine', 'virtue', 'principal', 'component', 'analysis', 'favorable', 'matching', 'property', 'high', 'dimensional', 'space', 'achieve', 'high', 'precision', 'recognition', 'object', 'represent', 'set', 'high', 'dimensional', 'iconic', 'feature', 'vector', 'comprise', 'response', 'derivative', 'gaussian', 'filter', 'range', 'orientation', 'scale', 'filter', 'show', 'form', 'eigenvector', 'arbitrary', 'image', 'contain', 'natural', 'man', 'structure', 'suit', 'indexing', 'disparate', 'domain', 'indexing', 'algorithm', 'use', 'active', 'vision', 'system', 'conjunction', 'modify', 'form', 'kanerva', 'sparse', 'distribute', 'memory', 'facilitate', 'interpolation', 'view', 'provide', 'convenient', 'platform', 'learn', 'association', 'object', 'appearance', 'identity', 'robustness', 'indexing', 'method', 'experimentally', 'confirm', 'subject', 'method', 'range', 'view', 'condition', 'accuracy', 'verify', 'know', 'model', 'database', 'contain', 'number', 'complex', 'object', 'varying', 'pose'], tags=['197']),
#  TaggedDocument(words=['siimplify', 'paterson', 'version', 'ajtai', 'komlos', 'szemeredi', 'sort', 'network', 'analysis', 'mainly', 'tune', 'invariant', 'maintain'], tags=['198']),
#  TaggedDocument(words=['temporal', 'projection', 'crucial', 'task', 'planning', 'order', 'achieve', 'goal', 'planner', 'able', 'reason', 'consequence', 'action', 'real', 'world', 'planner', 'complete', 'information', 'environment', 'consequence', 'action', 'planner', 'able', 'reason', 'probabilistic', 'nature', 'world', 'probabilistic', 'effect', 'action', 'interaction', 'action', 'event', 'world', 'probabilistic', 'temporally', 'complex', 'simultaneous', 'event', 'interact', 'different', 'way', 'depend', 'temporal', 'property', 'action', 'temporal', 'relation', 'precondition', 'effect', 'complex', 'exist', 'projection', 'system', 'weak', 'representation', 'temporally', 'complex', 'action', 'event', 'probabilistic', 'world', 'handle', 'probabilistic', 'situation', 'limited', 'representation', 'temporal', 'relation', 'handle', 'complex', 'temporal', 'relation', 'generally', 'assume', 'world', 'completely', 'deterministic', 'speed', 'exist', 'probabilistic', 'projection', 'system', 'low', 'system', 'impractical', 'scale', 'large', 'problem', 'thesis', 'propose', 'practical', 'projection', 'system', 'handle', 'probabilistic', 'nature', 'world', 'temporally', 'complex', 'nature', 'action', 'projection', 'base', 'simulation', 'method', 'projection', 'simulate', 'possible', 'course', 'event', 'time', 'simulation', 'trace', 'collect', 'process', 'projection', 'module', 'end', 'provide', 'planner', 'execution', 'monitor', 'probabilistic', 'estimate', 'proposition', 'value', 'representation', 'allow', 'system', 'rich', 'temporal', 'probabilistic', 'aspect'], tags=['199']),
#  TaggedDocument(words=['analyze', 'problem', 'compute', 'minimal', 'label', 'network', 'temporal', 'relation', 'point', 'algebra', 'van', 'beek', 'propose', 'algorithm', 'accomplish', 'task', 'take', 'time', 'point', 'proof', 'correctness', 'algorithm', 'give', 'van', 'beek', 'cohen', 'faulty', 'provide', 'new', 'proof', 'show', 'algorithm', 'correct'], tags=['200']),
#  TaggedDocument(words=['result', 'field', 'robust', 'statistic', 'derive', 'class', 'kalman', 'filter', 'robust', 'structured', 'unstructured', 'noise', 'input', 'datum', 'stream', 'filter', 'class', 'maintain', 'robust', 'optimal', 'estimate', 'input', 'process', 'hide', 'state', 'allow', 'measurement', 'covariance', 'matrix', 'non', 'linear', 'function', 'prediction', 'error', 'endow', 'filter', 'ability', 'reject', 'outlier', 'input', 'stream', 'simultaneously', 'filter', 'learn', 'internal', 'model', 'input', 'dynamic', 'adapt', 'measurement', 'state', 'transition', 'matrix', 'additional', 'kalman', 'filter', 'base', 'adaptation', 'rule', 'present', 'experimental', 'result', 'demonstrate', 'efficacy', 'filter', 'mediate', 'appearance', 'base', 'segmentation', 'recognition', 'object', 'image', 'sequence', 'presence', 'vary', 'degree', 'occlusion', 'clutter', 'noise'], tags=['201']),
#  TaggedDocument(words=['semantic', 'scene', 'classification', 'categorize', 'image', 'set', 'physical', 'indoor', 'outdoor', 'orientation', 'semantic', 'category', 'beach', 'party', 'relatively', 'new', 'field', 'exist', 'technique', 'primarily', 'low', 'level', 'feature', 'classify', 'scene', 'achieve', 'success', 'constrain', 'problem', 'report', 'state', 'art', 'present', 'summary', 'major', 'scene', 'classification', 'system', 'identify', 'feature', 'inference', 'engine', 'use'], tags=['202']),
#  TaggedDocument(words=['currently', 'trains', 'dialog', 'system', 'use', 'standard', 'chart', 'parser', 'interface', 'text', 'dialog', 'rest', 'dialog', 'processing', 'system', 'traditional', 'chart', 'parser', 'equipped', 'handle', 'dialog', 'dialog', 'constituent', 'discontinuous', 'intersperse', 'acknowledgment', 'edit', 'term', 'repair', 'etc', 'paper', 'propose', 'modification', 'current', 'trains', 'parser', 'enable', 'handle', 'discontinuous', 'dialog', 'structure', 'representation', 'dialog', 'superficially', 'hierarchical', 'consist', 'interleaved', 'structure', 'possible', 'device', 'accommodate', 'repair', 'uh', 'corning', 'explicit', 'grammar', 'rule', 'accommodate', 'mid', 'sentence', 'acknowledgment', 'okay', 'edit', 'term', 'uh', 'etc', 'trailer', 'attach', 'lexical', 'item', 'work', 'simple', 'sample', 'dialog', 'allow', 'repair', 'interruption', 'introduce', 'ambiguity', 'discuss', 'initial', 'disambiguation', 'technique'], tags=['203']),
#  TaggedDocument(words=['software', 'transactional', 'memory', 'system', 'enable', 'programmer', 'easily', 'write', 'concurrent', 'datum', 'structure', 'list', 'tree', 'hashtable', 'graph', 'non', 'conflicting', 'operation', 'proceed', 'parallel', 'structure', 'abstract', 'form', 'dictionary', 'transaction', 'associate', 'search', 'key', 'regroup', 'transaction', 'base', 'key', 'improve', 'locality', 'reduce', 'conflict', 'parallel', 'transaction', 'paper', 'present', 'executor', 'partition', 'transaction', 'available', 'processor', 'key', 'base', 'adaptive', 'partitioning', 'monitor', 'incoming', 'transaction', 'estimate', 'probability', 'distribution', 'key', 'adaptively', 'determine', 'usually', 'nonuniform', 'partition', 'compare', 'adaptive', 'partitioning', 'uniform', 'partitioning', 'round', 'robin', 'keyless', 'partition', 'sunfire', 'machine', 'demonstrate', 'key', 'base', 'adaptive', 'partitioning', 'significantly', 'improve', 'throughput', 'fine', 'grain', 'parallel', 'operation', 'concurrent', 'data', 'structure'], tags=['204']),
#  TaggedDocument(words=['common', 'feeling', 'animal', 'learn', 'feeling', 'emergence', 'computer', 'learn', 'paradigm', 'mimic', 'form', 'human', 'learning', 'raise', 'hope', 'learn', 'key', 'computer', 'vision', 'problem', 'clear', 'nature', 'program', 'visual', 'capability', 'genome', 'certainly', 'know', 'program', 'computer', 'close', 'form', 'solution', 'vision', 'problem', 'daunting', 'task', 'aim', 'informal', 'elementary', 'report', 'basically', 'term', 'paper', 'cast', 'doubt', 'idea', 'biological', 'system', 'learn', 'complex', 'process', 'development', 'begin', 'fertilization', 'end', 'mature', 'individual', 'consider', 'genetic', 'nature', 'learn', 'nurture', 'process', 'logical', 'endpoint', 'opposite', 'pole', 'report', 'consider', 'go', 'endpoint', 'mean', 'raise', 'possibility', 'understand', 'process', 'biology', 'responsible', 'visual', 'capability'], tags=['205']),
#  TaggedDocument(words=['discourse', 'marker', 'know', 'clue', 'word', 'extensively', 'human', 'human', 'task', 'orient', 'dialog', 'signal', 'structure', 'discourse', 'previous', 'work', 'show', 'importance', 'monologs', 'social', 'conversation', 'mark', 'discourse', 'structure', 'little', 'attention', 'pay', 'importance', 'spoken', 'dialog', 'system', 'paper', 'investigate', 'discourse', 'marker', 'signal', 'upcoming', 'speech', 'tend', 'task', 'orient', 'dialog', 'demonstrate', 'high', 'correlation', 'specific', 'discourse', 'marker', 'specific', 'conversational', 'move', 'discourse', 'marker', 'use', 'adjacency', 'pair', 'discourse', 'marker', 'speaker', 'orientation', 'information', 'present', 'prior', 'turn', 'limit', 'analysis', 'turn', 'initial', 'discourse', 'marker', 'discover', 'new', 'pattern', 'interaction', 'phenomena', 'specific', 'dialog'], tags=['206']),
#  TaggedDocument(words=['rhetorical', 'rhet', 'programming', 'knowledge', 'representation', 'system', 'offer', 'set', 'tool', 'building', 'automate', 'reasoning', 'system', 'emphasis', 'flexibility', 'representation', 'allow', 'user', 'decide', 'system', 'basically', 'operate', 'theorem', 'prover', 'frame', 'like', 'system', 'associative', 'network', 'rhet', 'end', 'user', 'programming', 'system', 'handle', 'knowledge', 'tation', 'chore', 'blow', 'programming', 'language', 'rhet', 'offer', 'major', 'mode', 'inference', 'horn', 'clause', 'theorem', 'prover', 'backwards', 'chain', 'mechanism', 'forward', 'chain', 'mechanism', 'mode', 'use', 'common', 'representation', 'fact', 'horn', 'clause', 'universally', 'quantify', 'potentially', 'type', 'restrict', 'variable', 'use', 'unification', 'algorithm', 'additionally', 'share', 'follow', 'additional', 'specialized', 'reasoning', 'capability', 'variable', 'type', 'fairly', 'general', 'type', 'theory', 'allow', 'limited', 'calculus', 'type', 'include', 'intersection', 'subtraction', 'reasoning', 'equality', 'ground', 'term', 'reason', 'context', 'space', 'access', 'axiom', 'term', 'parent', 'contexts', 'escape', 'lisp', 'use', 'necessary'], tags=['207']),
#  TaggedDocument(words=['combination', 'technique', 'visual', 'representation', 'view', 'synthesis', 'visual', 'motor', 'transfer', 'function', 'estimation', 'present', 'method', 'animate', 'movement', 'active', 'agent', 'robot', 'use', 'prior', 'model', 'explicit', 'information', 'information', 'need', 'generate', 'simulated', 'image', 'acquire', 'line', 'watch', 'agent', 'arbitrary', 'possibly', 'unrelated', 'task', 'present', 'experimental', 'result', 'synthesizing', 'image', 'sequence', 'movement', 'simulated', 'puma', 'robot', 'arm', 'joint', 'space', 'cartesian', 'world', 'coordinate', 'control', 'create', 'user', 'interface', 'user', 'input', 'robot', 'movement', 'program', 'execution', 'view', 'movie', 'simulate', 'robot', 'execute', 'program', 'instantaneous', 'dynamic', 'variable', 'simulated', 'robot'], tags=['208'])]

# %%
#Vector size: número de dimensões da embedding
#min_count: número mínimo de vezes que uma palavra deve aparecer na coleção para ser considerada no vocabulário
#dm: se 1 significa que será utilizado o modelo DM, e 0 significa a utilização do modelo DBOW
#dm_contate: 1 significa a concatenação dos vetores e 0 significa a média
model = Doc2Vec(vector_size=100, min_count=2, dm=1, dm_concat = 1,epochs=100)
model.build_vocab(tagged_treino)
model.train(tagged_treino,total_examples=model.corpus_count,epochs=model.iter)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   import sys

# %%
#Reduzindo o uso de memória
model.delete_temporary_training_data(keep_doctags_vectors=True, keep_inference=True)

# %%
#Retornando o vetor de um documento específico
model.docvecs['99']
# Out:
# array([-0.21350163,  0.518985  ,  0.2621769 , -0.50123894,  0.30604535,
#        -0.76276064, -0.03692596, -0.10289425, -0.22454019,  0.3223731 ,
#         0.21365316, -0.25018468,  0.03813893, -0.3744234 , -0.25857016,
#         0.31966877, -0.41107163,  0.16822456,  0.17201322,  0.20553581,
#        -0.1269353 , -0.4818998 ,  0.07511721,  0.3597196 , -0.33525798,
#         0.07259433, -0.03015873, -0.2753913 ,  0.627168  , -0.20994936,
#         0.30568287,  0.00772855, -0.41094124, -0.08683598,  0.03580499,
#         0.08384772,  0.3727823 ,  0.33311275, -0.02928626, -0.00911088,
#        -0.1693627 ,  0.16375813,  0.15085629,  0.4208998 , -0.5075453 ,
#        -0.1571005 , -0.11056541, -0.19484924,  0.4380839 ,  0.10833288,
#        -0.2776975 , -0.36709553, -0.04924485, -0.25200897,  0.07802427,
#        -0.46872866, -0.5469607 ,  0.05443887, -0.14133418, -0.13292979,
#         0.00105906,  0.01498361, -0.44271678, -0.12671605, -0.82263017,
#        -0.1720718 ,  0.11835211, -0.30545503, -0.11229146, -0.26905003,
#         0.3697636 , -0.21671109, -0.4985976 ,  0.17495899,  0.21517608,
#         0.6459091 ,  0.09456452, -0.05770521, -0.22798395, -0.38424748,
#        -0.3257967 , -0.12944853,  0.25251552,  0.28599438,  0.1157198 ,
#         0.5900801 , -0.13051133,  0.05120202, -0.45558992,  0.5546452 ,
#         0.13846534,  0.3688416 ,  0.30157748,  0.28734836,  0.24678324,
#         0.4942138 ,  0.42930636,  0.13791333,  0.287563  , -0.3862199 ],
#       dtype=float32)

# %%
len(tagged_treino)
# Out:
# 209

# %%
#Construindo a representação para o conjunto de treino
repr_treino = constuir_vetores_treino(model, tagged_treino, num_dim)

# %%
repr_treino
# Out:
# array([[-0.30389971,  0.06507325,  0.22577207, ..., -0.22264957,
#         -0.62324685,  0.24069855],
#        [-0.20261821, -0.25733793,  0.32939449, ..., -0.03577409,
#          0.04425891,  0.0586013 ],
#        [ 0.46279982,  0.22318052, -0.02561086, ...,  0.19592594,
#          0.46459264,  0.2526679 ],
#        ...,
#        [ 0.08866474,  0.09879918, -0.33386961, ..., -0.00601573,
#          0.17756955, -0.39717343],
#        [-0.26908183,  1.23868537,  0.09164279, ...,  0.53623676,
#          0.55227411, -0.07785906],
#        [ 0.26481882, -0.41381058, -0.06508511, ..., -0.07047043,
#         -0.13571241,  0.24601074]])

# %%
repr_treino.shape
# Out:
# (209, 100)

# %% [markdown]
# # Construindo um modelo de Classificação no Treino

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=7, metric='cosine')

# %%
classifier.fit(repr_treino, df_treino['class'])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='cosine',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %% [markdown]
# # Avaliando os resultados da classificação no conjunto de teste

# %% [markdown]
# ## Construindo a representação do conjunto de teste

# %%
tagged_teste = tagged_data(df_teste['text'])

# %%
repr_teste = constuir_vetores_teste(model, tagged_teste, num_dim)

# %%
repr_teste
# Out:
# array([[-0.0185711 ,  0.20279531, -0.42402735, ..., -1.3776629 ,
#         -0.67177463, -0.75650001],
#        [-0.16915292,  0.28923172, -0.48771727, ..., -0.65883189,
#         -0.92237693, -0.67874187],
#        [ 0.52248931, -0.0345635 , -0.00295892, ..., -0.98199719,
#         -0.61600173, -0.69399577],
#        ...,
#        [ 1.19139814, -1.7691282 , -0.9763096 , ..., -0.95323598,
#         -0.41137624,  0.44832253],
#        [ 0.47533625, -0.44106215, -1.22815061, ..., -1.88681746,
#         -2.02031088, -0.17406216],
#        [-0.69027042, -0.49125186,  0.96908212, ..., -1.43490148,
#         -0.18420385,  2.00309992]])

# %%
repr_teste.shape
# Out:
# (90, 100)

# %% [markdown]
# ## Predizendo a classe dos exemplos de teste

# %%
classifier.predict(repr_teste)
# Out:
# array(['ArtificiallIntelligence', 'ArtificiallIntelligence',
#        'ArtificiallIntelligence', 'Robotics', 'ArtificiallIntelligence',
#        'ArtificiallIntelligence', 'ArtificiallIntelligence', 'Robotics',
#        'Robotics', 'ArtificiallIntelligence', 'Robotics', 'Theory',
#        'Robotics', 'ArtificiallIntelligence', 'Theory', 'Robotics',
#        'ArtificiallIntelligence', 'Robotics', 'Robotics', 'Theory',
#        'Robotics', 'ArtificiallIntelligence', 'Theory', 'Robotics',
#        'Robotics', 'Theory', 'Robotics', 'Theory',
#        'ArtificiallIntelligence', 'ArtificiallIntelligence', 'Theory',
#        'ArtificiallIntelligence', 'Robotics', 'ArtificiallIntelligence',
#        'Robotics', 'Systems', 'Theory', 'ArtificiallIntelligence',
#        'Systems', 'Robotics', 'ArtificiallIntelligence',
#        'ArtificiallIntelligence', 'ArtificiallIntelligence', 'Robotics',
#        'Robotics', 'Robotics', 'Theory', 'ArtificiallIntelligence',
#        'Robotics', 'ArtificiallIntelligence', 'ArtificiallIntelligence',
#        'Theory', 'Robotics', 'ArtificiallIntelligence',
#        'ArtificiallIntelligence', 'Robotics', 'ArtificiallIntelligence',
#        'Theory', 'ArtificiallIntelligence', 'ArtificiallIntelligence',
#        'ArtificiallIntelligence', 'Robotics', 'Theory',
#        'ArtificiallIntelligence', 'ArtificiallIntelligence',
#        'ArtificiallIntelligence', 'Systems', 'ArtificiallIntelligence',
#        'ArtificiallIntelligence', 'Robotics', 'ArtificiallIntelligence',
#        'Robotics', 'Theory', 'ArtificiallIntelligence',
#        'ArtificiallIntelligence', 'Systems', 'ArtificiallIntelligence',
#        'ArtificiallIntelligence', 'ArtificiallIntelligence', 'Systems',
#        'Robotics', 'ArtificiallIntelligence', 'Robotics',
#        'ArtificiallIntelligence', 'Theory', 'ArtificiallIntelligence',
#        'ArtificiallIntelligence', 'Robotics', 'Robotics', 'Theory'],
#       dtype=object)

# %% [markdown]
# #Avaliando a performance da predição dos exemplos de teste

# %%
f1_score(df_teste['class'], classifier.predict(repr_teste), average='macro')
# Out:
# 0.7838974031502767

# %%
f1_score(df_teste['class'], classifier.predict(repr_teste), average='micro')
# Out:
# 0.7444444444444445

# %% [markdown]
# # Comparando com a BOW

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def preprocessamento2 (texto): 
  final_tokens = []
  doc = nlp(texto)
  for token in doc:
    if(token.is_alpha and not token.is_stop):
          final_tokens.append(token.lemma_.lower())
      
  return ' '.join(final_tokens)

# %%
vetorizador = TfidfVectorizer()

# %%
bow_treino = vetorizador.fit_transform(df_treino['text'].apply(preprocessamento2))

# %%
classifier.fit(bow_treino, df_treino['class'])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='cosine',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
repr_teste = vetorizador.transform(df_teste['class'].apply(preprocessamento2))
f1_score(df_teste['class'], classifier.predict(repr_teste), average='macro')
# Out:
# 0.446969696969697
